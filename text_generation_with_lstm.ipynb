# %% [markdown]
# <a href="https://colab.research.google.com/github/abulhasanat/NLP-Experiments/blob/master/text_generation_with_lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
keras.__version__
# Out:
# '2.3.1'

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import keras
import numpy as np

# %%
path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 1us/step
# Corpus length: 600893

# %%
import requests
text = requests.get("http://www.gutenberg.org/cache/epub/11/pg11.txt").text.lower()
# open("data/wonderland.txt", "w", encoding="utf-8").write(text)

# %%
text
# Out:
# '\ufeffproject gutenberg\'s alice\'s adventures in wonderland, by lewis carroll\r\n\r\nthis ebook is for the use of anyone anywhere at no cost and with\r\nalmost no restrictions whatsoever.  you may copy it, give it away or\r\nre-use it under the terms of the project gutenberg license included\r\nwith this ebook or online at www.gutenberg.org\r\n\r\n\r\ntitle: alice\'s adventures in wonderland\r\n\r\nauthor: lewis carroll\r\n\r\nposting date: june 25, 2008 [ebook #11]\r\nrelease date: march, 1994\r\n[last updated: december 20, 2011]\r\n\r\nlanguage: english\r\n\r\n\r\n*** start of this project gutenberg ebook alice\'s adventures in wonderland ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nalice\'s adventures in wonderland\r\n\r\nlewis carroll\r\n\r\nthe millennium fulcrum edition 3.0\r\n\r\n\r\n\r\n\r\nchapter i. down the rabbit-hole\r\n\r\nalice was beginning to get very tired of sitting by her sister on the\r\nbank, and of having nothing to do: once or twice she had peeped into the\r\nbook her sister was reading, but it had no pictures or conversations in\r\nit, \'and what is the use of a book,\' thought alice \'without pictures or\r\nconversations?\'\r\n\r\nso she was considering in her own mind (as well as she could, for the\r\nhot day made her feel very sleepy and stupid), whether the pleasure\r\nof making a daisy-chain would be worth the trouble of getting up and\r\npicking the daisies, when suddenly a white rabbit with pink eyes ran\r\nclose by her.\r\n\r\nthere was nothing so very remarkable in that; nor did alice think it so\r\nvery much out of the way to hear the rabbit say to itself, \'oh dear!\r\noh dear! i shall be late!\' (when she thought it over afterwards, it\r\noccurred to her that she ought to have wondered at this, but at the time\r\nit all seemed quite natural); but when the rabbit actually took a watch\r\nout of its waistcoat-pocket, and looked at it, and then hurried on,\r\nalice started to her feet, for it flashed across her mind that she had\r\nnever before seen a rabbit with either a waistcoat-pocket, or a watch\r\nto take out of it, and burning with curiosity, she ran across the field\r\nafter it, and fortunately was just in time to see it pop down a large\r\nrabbit-hole under the hedge.\r\n\r\nin another moment down went alice after it, never once considering how\r\nin the world she was to get out again.\r\n\r\nthe rabbit-hole went straight on like a tunnel for some way, and then\r\ndipped suddenly down, so suddenly that alice had not a moment to think\r\nabout stopping herself before she found herself falling down a very deep\r\nwell.\r\n\r\neither the well was very deep, or she fell very slowly, for she had\r\nplenty of time as she went down to look about her and to wonder what was\r\ngoing to happen next. first, she tried to look down and make out what\r\nshe was coming to, but it was too dark to see anything; then she\r\nlooked at the sides of the well, and noticed that they were filled with\r\ncupboards and book-shelves; here and there she saw maps and pictures\r\nhung upon pegs. she took down a jar from one of the shelves as\r\nshe passed; it was labelled \'orange marmalade\', but to her great\r\ndisappointment it was empty: she did not like to drop the jar for fear\r\nof killing somebody, so managed to put it into one of the cupboards as\r\nshe fell past it.\r\n\r\n\'well!\' thought alice to herself, \'after such a fall as this, i shall\r\nthink nothing of tumbling down stairs! how brave they\'ll all think me at\r\nhome! why, i wouldn\'t say anything about it, even if i fell off the top\r\nof the house!\' (which was very likely true.)\r\n\r\ndown, down, down. would the fall never come to an end! \'i wonder how\r\nmany miles i\'ve fallen by this time?\' she said aloud. \'i must be getting\r\nsomewhere near the centre of the earth. let me see: that would be four\r\nthousand miles down, i think--\' (for, you see, alice had learnt several\r\nthings of this sort in her lessons in the schoolroom, a ...

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 55819
# Unique characters: 60
# Vectorization...

# %%
sentences
# Out:
# ["\ufeffproject gutenberg's alice's adventures in wonderland, by le",
#  "oject gutenberg's alice's adventures in wonderland, by lewis",
#  "ct gutenberg's alice's adventures in wonderland, by lewis ca",
#  "gutenberg's alice's adventures in wonderland, by lewis carro",
#  "enberg's alice's adventures in wonderland, by lewis carroll\r",
#  "erg's alice's adventures in wonderland, by lewis carroll\r\n\r\n",
#  "'s alice's adventures in wonderland, by lewis carroll\r\n\r\nthi",
#  "alice's adventures in wonderland, by lewis carroll\r\n\r\nthis e",
#  "ce's adventures in wonderland, by lewis carroll\r\n\r\nthis eboo",
#  's adventures in wonderland, by lewis carroll\r\n\r\nthis ebook i',
#  'dventures in wonderland, by lewis carroll\r\n\r\nthis ebook is f',
#  'ntures in wonderland, by lewis carroll\r\n\r\nthis ebook is for ',
#  'res in wonderland, by lewis carroll\r\n\r\nthis ebook is for the',
#  ' in wonderland, by lewis carroll\r\n\r\nthis ebook is for the us',
#  ' wonderland, by lewis carroll\r\n\r\nthis ebook is for the use o',
#  'nderland, by lewis carroll\r\n\r\nthis ebook is for the use of a',
#  'rland, by lewis carroll\r\n\r\nthis ebook is for the use of anyo',
#  'nd, by lewis carroll\r\n\r\nthis ebook is for the use of anyone ',
#  ' by lewis carroll\r\n\r\nthis ebook is for the use of anyone any',
#  ' lewis carroll\r\n\r\nthis ebook is for the use of anyone anywhe',
#  'wis carroll\r\n\r\nthis ebook is for the use of anyone anywhere ',
#  ' carroll\r\n\r\nthis ebook is for the use of anyone anywhere at ',
#  'rroll\r\n\r\nthis ebook is for the use of anyone anywhere at no ',
#  'll\r\n\r\nthis ebook is for the use of anyone anywhere at no cos',
#  '\n\r\nthis ebook is for the use of anyone anywhere at no cost a',
#  'this ebook is for the use of anyone anywhere at no cost and ',
#  's ebook is for the use of anyone anywhere at no cost and wit',
#  'book is for the use of anyone anywhere at no cost and with\r\n',
#  'k is for the use of anyone anywhere at no cost and with\r\nalm',
#  's for the use of anyone anywhere at no cost and with\r\nalmost',
#  'or the use of anyone anywhere at no cost and with\r\nalmost no',
#  'the use of anyone anywhere at no cost and with\r\nalmost no re',
#  ' use of anyone anywhere at no cost and with\r\nalmost no restr',
#  'e of anyone anywhere at no cost and with\r\nalmost no restrict',
#  'f anyone anywhere at no cost and with\r\nalmost no restriction',
#  'nyone anywhere at no cost and with\r\nalmost no restrictions w',
#  'ne anywhere at no cost and with\r\nalmost no restrictions what',
#  'anywhere at no cost and with\r\nalmost no restrictions whatsoe',
#  'where at no cost and with\r\nalmost no restrictions whatsoever',
#  're at no cost and with\r\nalmost no restrictions whatsoever.  ',
#  'at no cost and with\r\nalmost no restrictions whatsoever.  you',
#  'no cost and with\r\nalmost no restrictions whatsoever.  you ma',
#  'cost and with\r\nalmost no restrictions whatsoever.  you may c',
#  't and with\r\nalmost no restrictions whatsoever.  you may copy',
#  'nd with\r\nalmost no restrictions whatsoever.  you may copy it',
#  'with\r\nalmost no restrictions whatsoever.  you may copy it, g',
#  'h\r\nalmost no restrictions whatsoever.  you may copy it, give',
#  'almost no restrictions whatsoever.  you may copy it, give it',
#  'ost no restrictions whatsoever.  you may copy it, give it aw',
#  ' no restrictions whatsoever.  you may copy it, give it away ',
#  ' restrictions whatsoever.  you may copy it, give it away or\r',
#  'strictions whatsoever.  you may copy it, give it away or\r\nre',
#  'ictions whatsoever.  you may copy it, give it away or\r\nre-us',
#  'ions whatsoever.  you may copy it, give it away or\r\nre-use i',
#  's whatsoever.  you may copy it, give it away or\r\nre-use it u',
#  'hatsoever.  you may copy it, give it away or\r\nre-use it unde',
#  'soever.  you may copy it, give it away or\r\nre-use it under t',
#  'ver.  you may copy it, give it away or\r\nre-use it under the ',
#  '.  you may copy it, give it away or\r\nre-use it under the ter',
#  'you may copy it, give it away or\r\nre-use it under the terms ',
#  ' may copy it, give it away or\r\nre-use it under the terms of ',
#  'y copy it, give it away or\r\nre-use it under the terms of the',
#  'opy it, give it away or\r\nre-use it under the terms of the pr',
#  ' it, give it away or\r\nre-use it under the terms of the proje',
#  ', give it away or\r\nre-use it under the terms of the project ',
#  'ive it away or\r\nre-use it under the terms of the project gut',
#  ' it away or\r\nre-use it under the terms of the project gutenb',
#  ' away or\r\nre-use it under the terms of the project gutenberg',
#  'ay or\r\nre-use it under the terms of the project gutenberg li',
#  'or\r\nre-use it under the terms of the project gutenberg licen',
#  '\nre-use it under the terms of the project gutenberg license ',
#  '-use it under the terms of the project gutenberg license inc',
#  'e it under the terms of the project gutenberg license includ',
#  't under the terms of the project gutenberg license included\r',
#  'nder the terms of the project gutenberg license included\r\nwi',
#  'r the terms of the project gutenberg license included\r\nwith ',
#  'he terms of the project gutenberg license included\r\nwith thi',
#  'terms of the project gutenberg license included\r\nwith this e',
#  'ms of the project gutenberg license included\r\nwith this eboo',
#  'of the project gutenberg license included\r\nwith this ebook o',
#  'the project gutenberg license included\r\nwith this ebook or o',
#  ' project gutenberg license included\r\nwith this ebook or onli',
#  'oject gutenberg license included\r\nwith this ebook or online ',
#  'ct gutenberg license included\r\nwith this ebook or online at ',
#  'gutenberg license included\r\nwith this ebook or online at www',
#  'enberg license included\r\nwith this ebook or online at www.gu',
#  'erg license included\r\nwith this ebook or online at www.guten',
#  ' license included\r\nwith this ebook or online at www.gutenber',
#  'cense included\r\nwith this ebook or online at www.gutenberg.o',
#  'se included\r\nwith this ebook or online at www.gutenberg.org\r',
#  'included\r\nwith this ebook or online at www.gutenberg.org\r\n\r\n',
#  'luded\r\nwith this ebook or online at www.gutenberg.org\r\n\r\n\r\nt',
#  'ed\r\nwith this ebook or online at www.gutenberg.org\r\n\r\n\r\ntitl',
#  '\nwith this ebook or online at www.gutenberg.org\r\n\r\n\r\ntitle: ',
#  'th this ebook or online at www.gutenberg.org\r\n\r\n\r\ntitle: ali',
#  "this ebook or online at www.gutenberg.org\r\n\r\n\r\ntitle: alice'",
#  "s ebook or online at www.gutenberg.org\r\n\r\n\r\ntitle: alice's a",
#  "book or online at www.gutenberg.org\r\n\r\n\r\ntitle: alice's adve",
#  "k or online at www.gutenberg.org\r\n\r\n\r\ntitle: alice's adventu",
#  "r online at www.gutenberg.org\r\n\r\n\r\ntitle: alice's adventures",
#  "nline at www.gutenberg.org\r\n\r\n\r\ntitle: alice's adventures in",
#  "ne at www.gutenberg.org\r\n\r\n\r\ntitle: alice's adventures in wo",
#  "at www.gutenberg.org\r\n\r\n\r\ntitle: alice's adventures in wonde",
#  "www.gutenberg.org\r\n\r\n\r\ntitle: alice's adventures in wonderla",
#  ".gutenberg.org\r\n\r\n\r\ntitle: alice's adventures in wonderland\r",
#  "tenberg.org\r\n\r\n\r\ntitle: alice's adventures in wonderland\r\n\r\n",
#  "berg.org\r\n\r\n\r\ntitle: alice's adventures in wonderland\r\n\r\naut",
#  "g.org\r\n\r\n\r\ntitle: alice's adventures in wonderland\r\n\r\nauthor",
#  "rg\r\n\r\n\r\ntitle: alice's adventures in wonderland\r\n\r\nauthor: l",
#  "\n\r\n\r\ntitle: alice's adventures in wonderland\r\n\r\nauthor: lewi",
#  "\r\ntitle: alice's adventures in wonderland\r\n\r\nauthor: lewis c",
#  "itle: alice's adventures in wonderland\r\n\r\nauthor: lewis carr",
#  "e: alice's adventures in wonderland\r\n\r\nauthor: lewis carroll",
#  "alice's adventures in wonderland\r\n\r\nauthor: lewis carroll\r\n\r",
#  "ce's adventures in wonderland\r\n\r\nauthor: lewis carroll\r\n\r\npo",
#  's adventures in wonderland\r\n\r\nauthor: lewis carroll\r\n\r\nposti',
#  'dventures in wonderland\r\n\r\nauthor: lewis carroll\r\n\r\nposting ',
#  'ntures in wonderland\r\n\r\nauthor: lewis carroll\r\n\r\nposting dat',
#  'res in wonderland\r\n\r\nauthor: lewis carroll\r\n\r\nposting date: ',
#  ' in wonderland\r\n\r\nauthor: lewis carroll\r\n\r\nposting date: jun',
#  ' wonderland\r\n\r\nauthor: lewis carroll\r\n\r\nposting date: june 2',
#  'nderland\r\n\r\nauthor: lewis carroll\r\n\r\nposting date: june 25, ',
#  'rland\r\n\r\nauthor: lewis carroll\r\n\r\nposting date: june 25, 200',
#  'nd\r\n\r\nauthor: lewis carroll\r\n\r\nposting date: june 25, 2008 [',
#  '\n\r\nauthor: lewis carroll\r\n\r\nposting date: june 25, 2008 [ebo',
#  'author: lewis carroll\r\n\r\nposting date: june 25, 2008 [ebook ',
#  'hor: lewis carroll\r\n\r\nposting date: june 25, 2008 [ebook #11',
#  ': lewis carroll\r\n\r\nposting date: june 25, 2008 [ebook #11]\r\n',
#  'ewis carroll\r\n\r\nposting date: june 25, 2008 [ebook #11]\r\nrel',
#  's carroll\r\n\r\nposting date: june 25, 2008 [ebook #11]\r\nreleas',
#  'arroll\r\n\r\nposting date: june 25, 2008 [ebook #11]\r\nrelease d',
#  'oll\r\n\r\nposting date: june 25, 2008 [ebook #11]\r\nrelease date',
#  '\r\n\r\nposting date: june 25, 2008 [ebook #11]\r\nrelease date: m',
#  '\nposting date: june 25, 2008 [ebook #11]\r\nrelease date: marc',
#  'sting date: june 25, 2008 [ebook #11]\r\nrelease date: march, ',
#  'ng date: june 25, 2008 [ebook #11]\r\nrelease date: march, 199',
#  'date: june 25, 2008 [ebook #11]\r\nrelease date: march, 1994\r\n',
#  'e: june 25, 2008 [ebook #11]\r\nrelease date: march, 1994\r\n[la',
#  'june 25, 2008 [ebook #11]\r\nrelease date: march, 1994\r\n[last ',
#  'e 25, 2008 [ebook #11]\r\nrelease date: march, 1994\r\n[last upd',
#  '5, 2008 [ebook #11]\r\nrelease date: march, 1994\r\n[last update',
#  '2008 [ebook #11]\r\nrelease date: march, 1994\r\n[last updated: ',
#  '8 [ebook #11]\r\nrelease date: march, 1994\r\n[last updated: dec',
#  'ebook #11]\r\nrelease date: march, 1994\r\n[last updated: decemb',
#  'ok #11]\r\nrelease date: march, 1994\r\n[last updated: december ',
#  '#11]\r\nrelease date: march, 1994\r\n[last updated: december 20,',
#  ']\r\nrelease date: march, 1994\r\n[last updated: december 20, 20',
#  'release date: march, 1994\r\n[last updated: december 20, 2011]',
#  'ease date: march, 1994\r\n[last updated: december 20, 2011]\r\n\r',
#  'e date: march, 1994\r\n[last updated: december 20, 2011]\r\n\r\nla',
#  'ate: march, 1994\r\n[last updated: december 20, 2011]\r\n\r\nlangu',
#  ': march, 1994\r\n[last updated: december 20, 2011]\r\n\r\nlanguage',
#  'arch, 1994\r\n[last updated: december 20, 2011]\r\n\r\nlanguage: e',
#  'h, 1994\r\n[last updated: december 20, 2011]\r\n\r\nlanguage: engl',
#  '1994\r\n[last updated: december 20, 2011]\r\n\r\nlanguage: english',
#  '4\r\n[last updated: december 20, 2011]\r\n\r\nlanguage: english\r\n\r',
#  '[last updated: december 20, 2011]\r\n\r\nlanguage: english\r\n\r\n\r\n',
#  'st updated: december 20, 2011]\r\n\r\nlanguage: english\r\n\r\n\r\n***',
#  'updated: december 20, 2011]\r\n\r\nlanguage: english\r\n\r\n\r\n*** st',
#  'ated: december 20, 2011]\r\n\r\nlanguage: english\r\n\r\n\r\n*** start',
#  'd: december 20, 2011]\r\n\r\nlanguage: english\r\n\r\n\r\n*** start of',
#  'december 20, 2011]\r\n\r\nlanguage: english\r\n\r\n\r\n*** start of th',
#  'ember 20, 2011]\r\n\r\nlanguage: english\r\n\r\n\r\n*** start of this ',
#  'er 20, 2011]\r\n\r\nlanguage: english\r\n\r\n\r\n*** start of this pro',
#  '20, 2011]\r\n\r\nlanguage: english\r\n\r\n\r\n*** start of this projec',
#  ' 2011]\r\n\r\nlanguage: english\r\n\r\n\r\n*** start of this project g',
#  '11]\r\n\r\nlanguage: english\r\n\r\n\r\n*** start of this project gute',
#  '\r\n\r\nlanguage: english\r\n\r\n\r\n*** start of this project gutenbe',
#  '\nlanguage: english\r\n\r\n\r\n*** start of this project gutenberg ',
#  'nguage: english\r\n\r\n\r\n*** start of this project gutenberg ebo',
#  'age: english\r\n\r\n\r\n*** start of this project gutenberg ebook ',
#  ': english\r\n\r\n\r\n*** start of this project gutenberg ebook ali',
#  "nglish\r\n\r\n\r\n*** start of this project gutenberg ebook alice'",
#  "ish\r\n\r\n\r\n*** start of this project gutenberg ebook alice's a",
#  "\r\n\r\n\r\n*** start of this project gutenberg ebook alice's adve",
#  "\n\r\n*** start of this project gutenberg ebook alice's adventu",
#  "*** start of this project gutenberg ebook alice's adventures",
#  " start of this project gutenberg ebook alice's adventures in",
#  "art of this project gutenberg ebook alice's adventures in wo",
#  " of this project gutenberg ebook alice's adventures in wonde",
#  " this project gutenberg ebook alice's adventures in wonderla",
#  "is project gutenberg ebook alice's adventures in wonderland ",
#  "project gutenberg ebook alice's adventures in wonderland ***",
#  "ject gutenberg ebook alice's adventures in wonderland ***\r\n\r",
#  "t gutenberg ebook alice's adventures in wonderland ***\r\n\r\n\r\n",
#  "utenberg ebook alice's adventures in wonderland ***\r\n\r\n\r\n\r\n\r",
#  "nberg ebook alice's adventures in wonderland ***\r\n\r\n\r\n\r\n\r\n\r\n",
#  "rg ebook alice's adventures in wonderland ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r",
#  "ebook alice's adventures in wonderland ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n",
#  "ok alice's adventures in wonderland ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r",
#  "alice's adventures in wonderland ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nal",
#  "ce's adventures in wonderland ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nalice",
#  "s adventures in wonderland ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nalice's ",
#  "dventures in wonderland ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nalice's adv",
#  "ntures in wonderland ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nalice's advent",
#  "res in wonderland ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nalice's adventure",
#  " in wonderland ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nalice's adventures i",
#  " wonderland ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nalice's adventures in w",
#  "nderland ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nalice's adventures in wond",
#  "rland ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nalice's adventures in wonderl",
#  "nd ***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nalice's adventures in wonderland",
#  "***\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nalice's adventures in wonderland\r\n\r",
#  "\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nalice's adventures in wonderland\r\n\r\nle",
#  "\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nalice's adventures in wonderland\r\n\r\nlewis",
#  "\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\nalice's adventures in wonderland\r\n\r\nlewis ca",
#  "\n\r\n\r\n\r\n\r\n\r\n\r\nalice's adventures in wonderland\r\n\r\nlewis carro",
#  "\r\n\r\n\r\n\r\n\r\nalice's adventures in wonderland\r\n\r\nlewis carroll\r",
#  "\n\r\n\r\n\r\nalice's adventures in wonderland\r\n\r\nlewis carroll\r\n\r\n",
#  "\r\n\r\nalice's adventures in wonderland\r\n\r\nlewis carroll\r\n\r\nthe",
#  "\nalice's adventures in wonderland\r\n\r\nlewis carroll\r\n\r\nthe mi",
#  "ice's adventures in wonderland\r\n\r\nlewis carroll\r\n\r\nthe mille",
#  "'s adventures in wonderland\r\n\r\nlewis carroll\r\n\r\nthe millenni",
#  'adventures in wonderland\r\n\r\nlewis carroll\r\n\r\nthe millennium ',
#  'entures in wonderland\r\n\r\nlewis carroll\r\n\r\nthe millennium ful',
#  'ures in wonderland\r\n\r\nlewis carroll\r\n\r\nthe millennium fulcru',
#  's in wonderland\r\n\r\nlewis carroll\r\n\r\nthe millennium fulcrum e',
#  'n wonderland\r\n\r\nlewis carroll\r\n\r\nthe millennium fulcrum edit',
#  'onderland\r\n\r\nlewis carroll\r\n\r\nthe millennium fulcrum edition',
#  'erland\r\n\r\nlewis carroll\r\n\r\nthe millennium fulcrum edition 3.',
#  'and\r\n\r\nlewis carroll\r\n\r\nthe millennium fulcrum edition 3.0\r\n',
#  '\r\n\r\nlewis carroll\r\n\r\nthe millennium fulcrum edition 3.0\r\n\r\n\r',
#  '\nlewis carroll\r\n\r\nthe millennium fulcrum edition 3.0\r\n\r\n\r\n\r\n',
#  'wis carroll\r\n\r\nthe millennium fulcrum edition 3.0\r\n\r\n\r\n\r\n\r\nc',
#  ' carroll\r\n\r\nthe millennium fulcrum edition 3.0\r\n\r\n\r\n\r\n\r\nchap',
#  'rroll\r\n\r\nthe millennium fulcrum edition 3.0\r\n\r\n\r\n\r\n\r\nchapter',
#  'll\r\n\r\nthe millennium fulcrum edition 3.0\r\n\r\n\r\n\r\n\r\nchapter i.',
#  '\n\r\nthe millennium fulcrum edition 3.0\r\n\r\n\r\n\r\n\r\nchapter i. do',
#  'the millennium fulcrum edition 3.0\r\n\r\n\r\n\r\n\r\nchapter i. down ',
#  ' millennium fulcrum edition 3.0\r\n\r\n\r\n\r\n\r\nchapter i. down the',
#  'llennium fulcrum edition 3.0\r\n\r\n\r\n\r\n\r\nchapter i. down the ra',
#  'nnium fulcrum edition 3.0\r\n\r\n\r\n\r\n\r\nchapter i. down the rabbi',
#  'um fulcrum edition 3.0\r\n\r\n\r\n\r\n\r\nchapter i. down the rabbit-h',
#  'fulcrum edition 3.0\r\n\r\n\r\n\r\n\r\nchapter i. down the rabbit-hole',
#  'crum edition 3.0\r\n\r\n\r\n\r\n\r\nchapter i. down the rabbit-hole\r\n\r',
#  'm edition 3.0\r\n\r\n\r\n\r\n\r\nchapter i. down the rabbit-hole\r\n\r\nal',
#  'dition 3.0\r\n\r\n\r\n\r\n\r\nchapter i. down the rabbit-hole\r\n\r\nalice',
#  'ion 3.0\r\n\r\n\r\n\r\n\r\nchapter i. down the rabbit-hole\r\n\r\nalice wa',
#  ' 3.0\r\n\r\n\r\n\r\n\r\nchapter i. down the rabbit-hole\r\n\r\nalice was b',
#  '0\r\n\r\n\r\n\r\n\r\nchapter i. down the rabbit-hole\r\n\r\nalice was begi',
#  '\r\n\r\n\r\n\r\nchapter i. down the rabbit-hole\r\n\r\nalice was beginni',
#  '\n\r\n\r\nchapter i. down the rabbit-hole\r\n\r\nalice was beginning ',
#  '\r\nchapter i. down the rabbit-hole\r\n\r\nalice was beginning to ',
#  'hapter i. down the rabbit-hole\r\n\r\nalice was beginning to get',
#  'ter i. down the rabbit-hole\r\n\r\nalice was beginning to get ve',
#  ' i. down the rabbit-hole\r\n\r\nalice was beginning to get very ',
#  ' down the rabbit-hole\r\n\r\nalice was beginning to get very tir',
#  'wn the rabbit-hole\r\n\r\nalice was beginning to get very tired ',
#  'the rabbit-hole\r\n\r\nalice was beginning to get very tired of ',
#  ' rabbit-hole\r\n\r\nalice was beginning to get very tired of sit',
#  'bbit-hole\r\n\r\nalice was beginning to get very tired of sittin',
#  't-hole\r\n\r\nalice was beginning to get very tired of sitting b',
#  'ole\r\n\r\nalice was beginning to get very tired of sitting by h',
#  '\r\n\r\nalice was beginning to get very tired of sitting by her ',
#  '\nalice was beginning to get very tired of sitting by her sis',
#  'ice was beginning to get very tired of sitting by her sister',
#  ' was beginning to get very tired of sitting by her sister on',
#  's beginning to get very tired of sitting by her sister on th',
#  'eginning to get very tired of sitting by her sister on the\r\n',
#  'nning to get very tired of sitting by her sister on the\r\nban',
#  'ng to get very tired of sitting by her sister on the\r\nbank, ',
#  'to get very tired of sitting by her sister on the\r\nbank, and',
#  'get very tired of sitting by her sister on the\r\nbank, and of',
#  ' very tired of sitting by her sister on the\r\nbank, and of ha',
#  'ry tired of sitting by her sister on the\r\nbank, and of havin',
#  'tired of sitting by her sister on the\r\nbank, and of having n',
#  'ed of sitting by her sister on the\r\nbank, and of having noth',
#  'of sitting by her sister on the\r\nbank, and of having nothing',
#  'sitting by her sister on the\r\nbank, and of having nothing to',
#  'ting by her sister on the\r\nbank, and of having nothing to do',
#  'g by her sister on the\r\nbank, and of having nothing to do: o',
#  'y her sister on the\r\nbank, and of having nothing to do: once',
#  'er sister on the\r\nbank, and of having nothing to do: once or',
#  'sister on the\r\nbank, and of having nothing to do: once or tw',
#  'ter on the\r\nbank, and of having nothing to do: once or twice',
#  ' on the\r\nbank, and of having nothing to do: once or twice sh',
#  ' the\r\nbank, and of having nothing to do: once or twice she h',
#  'e\r\nbank, and of having nothing to do: once or twice she had ',
#  'bank, and of having nothing to do: once or twice she had pee',
#  'k, and of having nothing to do: once or twice she had peeped',
#  'and of having nothing to do: once or twice she had peeped in',
#  ' of having nothing to do: once or twice she had peeped into ',
#  ' having nothing to do: once or twice she had peeped into the',
#  'ving nothing to do: once or twice she had peeped into the\r\nb',
#  'g nothing to do: once or twice she had peeped into the\r\nbook',
#  'othing to do: once or twice she had peeped into the\r\nbook he',
#  'ing to do: once or twice she had peeped into the\r\nbook her s',
#  ' to do: once or twice she had peeped into the\r\nbook her sist',
#  ' do: once or twice she had peeped into the\r\nbook her sister ',
#  ': once or twice she had peeped into the\r\nbook her sister was',
#  'nce or twice she had peeped into the\r\nbook her sister was re',
#  ' or twice she had peeped into the\r\nbook her sister was readi',
#  ' twice she had peeped into the\r\nbook her sister was reading,',
#  'ice she had peeped into the\r\nbook her sister was reading, bu',
#  ' she had peeped into the\r\nbook her sister was reading, but i',
#  'e had peeped into the\r\nbook her sister was reading, but it h',
#  'ad peeped into the\r\nbook her sister was reading, but it had ',
#  'peeped into the\r\nbook her sister was reading, but it had no ',
#  'ped into the\r\nbook her sister was reading, but it had no pic',
#  ' into the\r\nbook her sister was reading, but it had no pictur',
#  'to the\r\nbook her sister was reading, but it had no pictures ',
#  'the\r\nbook her sister was reading, but it had no pictures or ',
#  '\r\nbook her sister was reading, but it had no pictures or con',
#  'ook her sister was reading, but it had no pictures or conver',
#  ' her sister was reading, but it had no pictures or conversat',
#  'r sister was reading, but it had no pictures or conversation',
#  'ister was reading, but it had no pictures or conversations i',
#  'er was reading, but it had no pictures or conversations in\r\n',
#  'was reading, but it had no pictures or conversations in\r\nit,',
#  " reading, but it had no pictures or conversations in\r\nit, 'a",
#  "ading, but it had no pictures or conversations in\r\nit, 'and ",
#  "ng, but it had no pictures or conversations in\r\nit, 'and wha",
#  " but it had no pictures or conversations in\r\nit, 'and what i",
#  "t it had no pictures or conversations in\r\nit, 'and what is t",
#  "t had no pictures or conversations in\r\nit, 'and what is the ",
#  "ad no pictures or conversations in\r\nit, 'and what is the use",
#  "no pictures or conversations in\r\nit, 'and what is the use of",
#  "pictures or conversations in\r\nit, 'and what is the use of a ",
#  "tures or conversations in\r\nit, 'and what is the use of a boo",
#  "es or conversations in\r\nit, 'and what is the use of a book,'",
#  "or conversations in\r\nit, 'and what is the use of a book,' th",
#  "conversations in\r\nit, 'and what is the use of a book,' thoug",
#  "versations in\r\nit, 'and what is the use of a book,' thought ",
#  "sations in\r\nit, 'and what is the use of a book,' thought ali",
#  "ions in\r\nit, 'and what is the use of a book,' thought alice ",
#  "s in\r\nit, 'and what is the use of a book,' thought alice 'wi",
#  "n\r\nit, 'and what is the use of a book,' thought alice 'witho",
#  "it, 'and what is the use of a book,' thought alice 'without ",
#  " 'and what is the use of a book,' thought alice 'without pic",
#  "nd what is the use of a book,' thought alice 'without pictur",
#  "what is the use of a book,' thought alice 'without pictures ",
#  "t is the use of a book,' thought alice 'without pictures or\r",
#  "s the use of a book,' thought alice 'without pictures or\r\nco",
#  "he use of a book,' thought alice 'without pictures or\r\nconve",
#  "use of a book,' thought alice 'without pictures or\r\nconversa",
#  " of a book,' thought alice 'without pictures or\r\nconversatio",
#  " a book,' thought alice 'without pictures or\r\nconversations?",
#  "book,' thought alice 'without pictures or\r\nconversations?'\r\n",
#  "k,' thought alice 'without pictures or\r\nconversations?'\r\n\r\ns",
#  " thought alice 'without pictures or\r\nconversations?'\r\n\r\nso s",
#  "ought alice 'without pictures or\r\nconversations?'\r\n\r\nso she ",
#  "ht alice 'without pictures or\r\nconversations?'\r\n\r\nso she was",
#  "alice 'without pictures or\r\nconversations?'\r\n\r\nso she was co",
#  "ce 'without pictures or\r\nconversations?'\r\n\r\nso she was consi",
#  "'without pictures or\r\nconversations?'\r\n\r\nso she was consider",
#  "thout pictures or\r\nconversations?'\r\n\r\nso she was considering",
#  "ut pictures or\r\nconversations?'\r\n\r\nso she was considering in",
#  "pictures or\r\nconversations?'\r\n\r\nso she was considering in he",
#  "tures or\r\nconversations?'\r\n\r\nso she was considering in her o",
#  "es or\r\nconversations?'\r\n\r\nso she was considering in her own ",
#  "or\r\nconversations?'\r\n\r\nso she was considering in her own min",
#  "\nconversations?'\r\n\r\nso she was considering in her own mind (",
#  "nversations?'\r\n\r\nso she was considering in her own mind (as ",
#  "rsations?'\r\n\r\nso she was considering in her own mind (as wel",
#  "tions?'\r\n\r\nso she was considering in her own mind (as well a",
#  "ns?'\r\n\r\nso she was considering in her own mind (as well as s",
#  "'\r\n\r\nso she was considering in her own mind (as well as she ",
#  '\r\nso she was considering in her own mind (as well as she cou',
#  'o she was considering in her own mind (as well as she could,',
#  'he was considering in her own mind (as well as she could, fo',
#  'was considering in her own mind (as well as she could, for t',
#  ' considering in her own mind (as well as she could, for the\r',
#  'nsidering in her own mind (as well as she could, for the\r\nho',
#  'dering in her own mind (as well as she could, for the\r\nhot d',
#  'ing in her own mind (as well as she could, for the\r\nhot day ',
#  ' in her own mind (as well as she could, for the\r\nhot day mad',
#  ' her own mind (as well as she could, for the\r\nhot day made h',
#  'r own mind (as well as she could, for the\r\nhot day made her ',
#  'wn mind (as well as she could, for the\r\nhot day made her fee',
#  'mind (as well as she could, for the\r\nhot day made her feel v',
#  'd (as well as she could, for the\r\nhot day made her feel very',
#  'as well as she could, for the\r\nhot day made her feel very sl',
#  'well as she could, for the\r\nhot day made her feel very sleep',
#  'l as she could, for the\r\nhot day made her feel very sleepy a',
#  's she could, for the\r\nhot day made her feel very sleepy and ',
#  'he could, for the\r\nhot day made her feel very sleepy and stu',
#  'could, for the\r\nhot day made her feel very sleepy and stupid',
#  'ld, for the\r\nhot day made her feel very sleepy and stupid), ',
#  ' for the\r\nhot day made her feel very sleepy and stupid), whe',
#  'r the\r\nhot day made her feel very sleepy and stupid), whethe',
#  'he\r\nhot day made her feel very sleepy and stupid), whether t',
#  '\nhot day made her feel very sleepy and stupid), whether the ',
#  't day made her feel very sleepy and stupid), whether the ple',
#  'ay made her feel very sleepy and stupid), whether the pleasu',
#  'made her feel very sleepy and stupid), whether the pleasure\r',
#  'e her feel very sleepy and stupid), whether the pleasure\r\nof',
#  'er feel very sleepy and stupid), whether the pleasure\r\nof ma',
#  'feel very sleepy and stupid), whether the pleasure\r\nof makin',
#  'l very sleepy and stupid), whether the pleasure\r\nof making a',
#  'ery sleepy and stupid), whether the pleasure\r\nof making a da',
#  ' sleepy and stupid), whether the pleasure\r\nof making a daisy',
#  'eepy and stupid), whether the pleasure\r\nof making a daisy-ch',
#  'y and stupid), whether the pleasure\r\nof making a daisy-chain',
#  'nd stupid), whether the pleasure\r\nof making a daisy-chain wo',
#  'stupid), whether the pleasure\r\nof making a daisy-chain would',
#  'pid), whether the pleasure\r\nof making a daisy-chain would be',
#  '), whether the pleasure\r\nof making a daisy-chain would be wo',
#  'whether the pleasure\r\nof making a daisy-chain would be worth',
#  'ther the pleasure\r\nof making a daisy-chain would be worth th',
#  'r the pleasure\r\nof making a daisy-chain would be worth the t',
#  'he pleasure\r\nof making a daisy-chain would be worth the trou',
#  'pleasure\r\nof making a daisy-chain would be worth the trouble',
#  'asure\r\nof making a daisy-chain would be worth the trouble of',
#  're\r\nof making a daisy-chain would be worth the trouble of ge',
#  '\nof making a daisy-chain would be worth the trouble of getti',
#  ' making a daisy-chain would be worth the trouble of getting ',
#  'king a daisy-chain would be worth the trouble of getting up ',
#  'g a daisy-chain would be worth the trouble of getting up and',
#  ' daisy-chain would be worth the trouble of getting up and\r\np',
#  'isy-chain would be worth the trouble of getting up and\r\npick',
#  '-chain would be worth the trouble of getting up and\r\npicking',
#  'ain would be worth the trouble of getting up and\r\npicking th',
#  ' would be worth the trouble of getting up and\r\npicking the d',
#  'uld be worth the trouble of getting up and\r\npicking the dais',
#  ' be worth the trouble of getting up and\r\npicking the daisies',
#  ' worth the trouble of getting up and\r\npicking the daisies, w',
#  'rth the trouble of getting up and\r\npicking the daisies, when',
#  ' the trouble of getting up and\r\npicking the daisies, when su',
#  'e trouble of getting up and\r\npicking the daisies, when sudde',
#  'rouble of getting up and\r\npicking the daisies, when suddenly',
#  'ble of getting up and\r\npicking the daisies, when suddenly a ',
#  ' of getting up and\r\npicking the daisies, when suddenly a whi',
#  ' getting up and\r\npicking the daisies, when suddenly a white ',
#  'tting up and\r\npicking the daisies, when suddenly a white rab',
#  'ng up and\r\npicking the daisies, when suddenly a white rabbit',
#  'up and\r\npicking the daisies, when suddenly a white rabbit wi',
#  'and\r\npicking the daisies, when suddenly a white rabbit with ',
#  '\r\npicking the daisies, when suddenly a white rabbit with pin',
#  'icking the daisies, when suddenly a white rabbit with pink e',
#  'ing the daisies, when suddenly a white rabbit with pink eyes',
#  ' the daisies, when suddenly a white rabbit with pink eyes ra',
#  'e daisies, when suddenly a white rabbit with pink eyes ran\r\n',
#  'aisies, when suddenly a white rabbit with pink eyes ran\r\nclo',
#  'ies, when suddenly a white rabbit with pink eyes ran\r\nclose ',
#  ', when suddenly a white rabbit with pink eyes ran\r\nclose by ',
#  'hen suddenly a white rabbit with pink eyes ran\r\nclose by her',
#  ' suddenly a white rabbit with pink eyes ran\r\nclose by her.\r\n',
#  'ddenly a white rabbit with pink eyes ran\r\nclose by her.\r\n\r\nt',
#  'nly a white rabbit with pink eyes ran\r\nclose by her.\r\n\r\nther',
#  ' a white rabbit with pink eyes ran\r\nclose by her.\r\n\r\nthere w',
#  'white rabbit with pink eyes ran\r\nclose by her.\r\n\r\nthere was ',
#  'te rabbit with pink eyes ran\r\nclose by her.\r\n\r\nthere was not',
#  'rabbit with pink eyes ran\r\nclose by her.\r\n\r\nthere was nothin',
#  'bit with pink eyes ran\r\nclose by her.\r\n\r\nthere was nothing s',
#  ' with pink eyes ran\r\nclose by her.\r\n\r\nthere was nothing so v',
#  'th pink eyes ran\r\nclose by her.\r\n\r\nthere was nothing so very',
#  'pink eyes ran\r\nclose by her.\r\n\r\nthere was nothing so very re',
#  'k eyes ran\r\nclose by her.\r\n\r\nthere was nothing so very remar',
#  'yes ran\r\nclose by her.\r\n\r\nthere was nothing so very remarkab',
#  ' ran\r\nclose by her.\r\n\r\nthere was nothing so very remarkable ',
#  'n\r\nclose by her.\r\n\r\nthere was nothing so very remarkable in ',
#  'close by her.\r\n\r\nthere was nothing so very remarkable in tha',
#  'se by her.\r\n\r\nthere was nothing so very remarkable in that; ',
#  'by her.\r\n\r\nthere was nothing so very remarkable in that; nor',
#  'her.\r\n\r\nthere was nothing so very remarkable in that; nor di',
#  '.\r\n\r\nthere was nothing so very remarkable in that; nor did a',
#  '\r\nthere was nothing so very remarkable in that; nor did alic',
#  'here was nothing so very remarkable in that; nor did alice t',
#  'e was nothing so very remarkable in that; nor did alice thin',
#  'as nothing so very remarkable in that; nor did alice think i',
#  'nothing so very remarkable in that; nor did alice think it s',
#  'hing so very remarkable in that; nor did alice think it so\r\n',
#  'g so very remarkable in that; nor did alice think it so\r\nver',
#  'o very remarkable in that; nor did alice think it so\r\nvery m',
#  'ery remarkable in that; nor did alice think it so\r\nvery much',
#  ' remarkable in that; nor did alice think it so\r\nvery much ou',
#  'markable in that; nor did alice think it so\r\nvery much out o',
#  'kable in that; nor did alice think it so\r\nvery much out of t',
#  'le in that; nor did alice think it so\r\nvery much out of the ',
#  'in that; nor did alice think it so\r\nvery much out of the way',
#  'that; nor did alice think it so\r\nvery much out of the way to',
#  't; nor did alice think it so\r\nvery much out of the way to he',
#  'nor did alice think it so\r\nvery much out of the way to hear ',
#  ' did alice think it so\r\nvery much out of the way to hear the',
#  'd alice think it so\r\nvery much out of the way to hear the ra',
#  'lice think it so\r\nvery much out of the way to hear the rabbi',
#  'e think it so\r\nvery much out of the way to hear the rabbit s',
#  'hink it so\r\nvery much out of the way to hear the rabbit say ',
#  'k it so\r\nvery much out of the way to hear the rabbit say to ',
#  't so\r\nvery much out of the way to hear the rabbit say to its',
#  'o\r\nvery much out of the way to hear the rabbit say to itself',
#  "very much out of the way to hear the rabbit say to itself, '",
#  "y much out of the way to hear the rabbit say to itself, 'oh ",
#  "uch out of the way to hear the rabbit say to itself, 'oh dea",
#  " out of the way to hear the rabbit say to itself, 'oh dear!\r",
#  "t of the way to hear the rabbit say to itself, 'oh dear!\r\noh",
#  "f the way to hear the rabbit say to itself, 'oh dear!\r\noh de",
#  "he way to hear the rabbit say to itself, 'oh dear!\r\noh dear!",
#  "way to hear the rabbit say to itself, 'oh dear!\r\noh dear! i ",
#  " to hear the rabbit say to itself, 'oh dear!\r\noh dear! i sha",
#  " hear the rabbit say to itself, 'oh dear!\r\noh dear! i shall ",
#  "ar the rabbit say to itself, 'oh dear!\r\noh dear! i shall be ",
#  "the rabbit say to itself, 'oh dear!\r\noh dear! i shall be lat",
#  " rabbit say to itself, 'oh dear!\r\noh dear! i shall be late!'",
#  "bbit say to itself, 'oh dear!\r\noh dear! i shall be late!' (w",
#  "t say to itself, 'oh dear!\r\noh dear! i shall be late!' (when",
#  "ay to itself, 'oh dear!\r\noh dear! i shall be late!' (when sh",
#  "to itself, 'oh dear!\r\noh dear! i shall be late!' (when she t",
#  "itself, 'oh dear!\r\noh dear! i shall be late!' (when she thou",
#  "elf, 'oh dear!\r\noh dear! i shall be late!' (when she thought",
#  ", 'oh dear!\r\noh dear! i shall be late!' (when she thought it",
#  "oh dear!\r\noh dear! i shall be late!' (when she thought it ov",
#  "dear!\r\noh dear! i shall be late!' (when she thought it over ",
#  "r!\r\noh dear! i shall be late!' (when she thought it over aft",
#  "\noh dear! i shall be late!' (when she thought it over afterw",
#  " dear! i shall be late!' (when she thought it over afterward",
#  "ar! i shall be late!' (when she thought it over afterwards, ",
#  " i shall be late!' (when she thought it over afterwards, it\r",
#  "shall be late!' (when she thought it over afterwards, it\r\noc",
#  "ll be late!' (when she thought it over afterwards, it\r\noccur",
#  "be late!' (when she thought it over afterwards, it\r\noccurred",
#  "late!' (when she thought it over afterwards, it\r\noccurred to",
#  "e!' (when she thought it over afterwards, it\r\noccurred to he",
#  ' (when she thought it over afterwards, it\r\noccurred to her t',
#  'hen she thought it over afterwards, it\r\noccurred to her that',
#  ' she thought it over afterwards, it\r\noccurred to her that sh',
#  'e thought it over afterwards, it\r\noccurred to her that she o',
#  'hought it over afterwards, it\r\noccurred to her that she ough',
#  'ght it over afterwards, it\r\noccurred to her that she ought t',
#  ' it over afterwards, it\r\noccurred to her that she ought to h',
#  ' over afterwards, it\r\noccurred to her that she ought to have',
#  'er afterwards, it\r\noccurred to her that she ought to have wo',
#  'afterwards, it\r\noccurred to her that she ought to have wonde',
#  'erwards, it\r\noccurred to her that she ought to have wondered',
#  'ards, it\r\noccurred to her that she ought to have wondered at',
#  's, it\r\noccurred to her that she ought to have wondered at th',
#  'it\r\noccurred to her that she ought to have wondered at this,',
#  '\noccurred to her that she ought to have wondered at this, bu',
#  'curred to her that she ought to have wondered at this, but a',
#  'red to her that she ought to have wondered at this, but at t',
#  ' to her that she ought to have wondered at this, but at the ',
#  ' her that she ought to have wondered at this, but at the tim',
#  'r that she ought to have wondered at this, but at the time\r\n',
#  'hat she ought to have wondered at this, but at the time\r\nit ',
#  ' she ought to have wondered at this, but at the time\r\nit all',
#  'e ought to have wondered at this, but at the time\r\nit all se',
#  'ught to have wondered at this, but at the time\r\nit all seeme',
#  't to have wondered at this, but at the time\r\nit all seemed q',
#  'o have wondered at this, but at the time\r\nit all seemed quit',
#  'ave wondered at this, but at the time\r\nit all seemed quite n',
#  ' wondered at this, but at the time\r\nit all seemed quite natu',
#  'ndered at this, but at the time\r\nit all seemed quite natural',
#  'red at this, but at the time\r\nit all seemed quite natural); ',
#  ' at this, but at the time\r\nit all seemed quite natural); but',
#  ' this, but at the time\r\nit all seemed quite natural); but wh',
#  'is, but at the time\r\nit all seemed quite natural); but when ',
#  ' but at the time\r\nit all seemed quite natural); but when the',
#  't at the time\r\nit all seemed quite natural); but when the ra',
#  't the time\r\nit all seemed quite natural); but when the rabbi',
#  'he time\r\nit all seemed quite natural); but when the rabbit a',
#  'time\r\nit all seemed quite natural); but when the rabbit actu',
#  'e\r\nit all seemed quite natural); but when the rabbit actuall',
#  'it all seemed quite natural); but when the rabbit actually t',
#  'all seemed quite natural); but when the rabbit actually took',
#  ' seemed quite natural); but when the rabbit actually took a ',
#  'emed quite natural); but when the rabbit actually took a wat',
#  'd quite natural); but when the rabbit actually took a watch\r',
#  'uite natural); but when the rabbit actually took a watch\r\nou',
#  'e natural); but when the rabbit actually took a watch\r\nout o',
#  'atural); but when the rabbit actually took a watch\r\nout of i',
#  'ral); but when the rabbit actually took a watch\r\nout of its ',
#  '); but when the rabbit actually took a watch\r\nout of its wai',
#  'but when the rabbit actually took a watch\r\nout of its waistc',
#  ' when the rabbit actually took a watch\r\nout of its waistcoat',
#  'en the rabbit actually took a watch\r\nout of its waistcoat-po',
#  'the rabbit actually took a watch\r\nout of its waistcoat-pocke',
#  ' rabbit actually took a watch\r\nout of its waistcoat-pocket, ',
#  'bbit actually took a watch\r\nout of its waistcoat-pocket, and',
#  't actually took a watch\r\nout of its waistcoat-pocket, and lo',
#  'ctually took a watch\r\nout of its waistcoat-pocket, and looke',
#  'ally took a watch\r\nout of its waistcoat-pocket, and looked a',
#  'y took a watch\r\nout of its waistcoat-pocket, and looked at i',
#  'ook a watch\r\nout of its waistcoat-pocket, and looked at it, ',
#  ' a watch\r\nout of its waistcoat-pocket, and looked at it, and',
#  'watch\r\nout of its waistcoat-pocket, and looked at it, and th',
#  'ch\r\nout of its waistcoat-pocket, and looked at it, and then ',
#  '\nout of its waistcoat-pocket, and looked at it, and then hur',
#  't of its waistcoat-pocket, and looked at it, and then hurrie',
#  'f its waistcoat-pocket, and looked at it, and then hurried o',
#  'ts waistcoat-pocket, and looked at it, and then hurried on,\r',
#  'waistcoat-pocket, and looked at it, and then hurried on,\r\nal',
#  'stcoat-pocket, and looked at it, and then hurried on,\r\nalice',
#  'oat-pocket, and looked at it, and then hurried on,\r\nalice st',
#  '-pocket, and looked at it, and then hurried on,\r\nalice start',
#  'cket, and looked at it, and then hurried on,\r\nalice started ',
#  't, and looked at it, and then hurried on,\r\nalice started to ',
#  'and looked at it, and then hurried on,\r\nalice started to her',
#  ' looked at it, and then hurried on,\r\nalice started to her fe',
#  'oked at it, and then hurried on,\r\nalice started to her feet,',
#  'd at it, and then hurried on,\r\nalice started to her feet, fo',
#  't it, and then hurried on,\r\nalice started to her feet, for i',
#  't, and then hurried on,\r\nalice started to her feet, for it f',
#  'and then hurried on,\r\nalice started to her feet, for it flas',
#  ' then hurried on,\r\nalice started to her feet, for it flashed',
#  'en hurried on,\r\nalice started to her feet, for it flashed ac',
#  'hurried on,\r\nalice started to her feet, for it flashed acros',
#  'ried on,\r\nalice started to her feet, for it flashed across h',
#  'd on,\r\nalice started to her feet, for it flashed across her ',
#  'n,\r\nalice started to her feet, for it flashed across her min',
#  '\nalice started to her feet, for it flashed across her mind t',
#  'ice started to her feet, for it flashed across her mind that',
#  ' started to her feet, for it flashed across her mind that sh',
#  'arted to her feet, for it flashed across her mind that she h',
#  'ed to her feet, for it flashed across her mind that she had\r',
#  'to her feet, for it flashed across her mind that she had\r\nne',
#  'her feet, for it flashed across her mind that she had\r\nnever',
#  ' feet, for it flashed across her mind that she had\r\nnever be',
#  'et, for it flashed across her mind that she had\r\nnever befor',
#  ' for it flashed across her mind that she had\r\nnever before s',
#  'r it flashed across her mind that she had\r\nnever before seen',
#  't flashed across her mind that she had\r\nnever before seen a ',
#  'lashed across her mind that she had\r\nnever before seen a rab',
#  'hed across her mind that she had\r\nnever before seen a rabbit',
#  ' across her mind that she had\r\nnever before seen a rabbit wi',
#  'ross her mind that she had\r\nnever before seen a rabbit with ',
#  's her mind that she had\r\nnever before seen a rabbit with eit',
#  'er mind that she had\r\nnever before seen a rabbit with either',
#  'mind that she had\r\nnever before seen a rabbit with either a ',
#  'd that she had\r\nnever before seen a rabbit with either a wai',
#  'hat she had\r\nnever before seen a rabbit with either a waistc',
#  ' she had\r\nnever before seen a rabbit with either a waistcoat',
#  'e had\r\nnever before seen a rabbit with either a waistcoat-po',
#  'ad\r\nnever before seen a rabbit with either a waistcoat-pocke',
#  '\nnever before seen a rabbit with either a waistcoat-pocket, ',
#  'ver before seen a rabbit with either a waistcoat-pocket, or ',
#  ' before seen a rabbit with either a waistcoat-pocket, or a w',
#  'fore seen a rabbit with either a waistcoat-pocket, or a watc',
#  'e seen a rabbit with either a waistcoat-pocket, or a watch\r\n',
#  'een a rabbit with either a waistcoat-pocket, or a watch\r\nto ',
#  ' a rabbit with either a waistcoat-pocket, or a watch\r\nto tak',
#  'rabbit with either a waistcoat-pocket, or a watch\r\nto take o',
#  'bit with either a waistcoat-pocket, or a watch\r\nto take out ',
#  ' with either a waistcoat-pocket, or a watch\r\nto take out of ',
#  'th either a waistcoat-pocket, or a watch\r\nto take out of it,',
#  'either a waistcoat-pocket, or a watch\r\nto take out of it, an',
#  'her a waistcoat-pocket, or a watch\r\nto take out of it, and b',
#  ' a waistcoat-pocket, or a watch\r\nto take out of it, and burn',
#  'waistcoat-pocket, or a watch\r\nto take out of it, and burning',
#  'stcoat-pocket, or a watch\r\nto take out of it, and burning wi',
#  'oat-pocket, or a watch\r\nto take out of it, and burning with ',
#  '-pocket, or a watch\r\nto take out of it, and burning with cur',
#  'cket, or a watch\r\nto take out of it, and burning with curios',
#  't, or a watch\r\nto take out of it, and burning with curiosity',
#  'or a watch\r\nto take out of it, and burning with curiosity, s',
#  'a watch\r\nto take out of it, and burning with curiosity, she ',
#  'atch\r\nto take out of it, and burning with curiosity, she ran',
#  'h\r\nto take out of it, and burning with curiosity, she ran ac',
#  'to take out of it, and burning with curiosity, she ran acros',
#  'take out of it, and burning with curiosity, she ran across t',
#  'e out of it, and burning with curiosity, she ran across the ',
#  'ut of it, and burning with curiosity, she ran across the fie',
#  'of it, and burning with curiosity, she ran across the field\r',
#  'it, and burning with curiosity, she ran across the field\r\naf',
#  ' and burning with curiosity, she ran across the field\r\nafter',
#  'd burning with curiosity, she ran across the field\r\nafter it',
#  'urning with curiosity, she ran across the field\r\nafter it, a',
#  'ing with curiosity, she ran across the field\r\nafter it, and ',
#  ' with curiosity, she ran across the field\r\nafter it, and for',
#  'th curiosity, she ran across the field\r\nafter it, and fortun',
#  'curiosity, she ran across the field\r\nafter it, and fortunate',
#  'iosity, she ran across the field\r\nafter it, and fortunately ',
#  'ity, she ran across the field\r\nafter it, and fortunately was',
#  ', she ran across the field\r\nafter it, and fortunately was ju',
#  'he ran across the field\r\nafter it, and fortunately was just ',
#  'ran across the field\r\nafter it, and fortunately was just in ',
#  ' across the field\r\nafter it, and fortunately was just in tim',
#  'ross the field\r\nafter it, and fortunately was just in time t',
#  's the field\r\nafter it, and fortunately was just in time to s',
#  'he field\r\nafter it, and fortunately was just in time to see ',
#  'field\r\nafter it, and fortunately was just in time to see it ',
#  'ld\r\nafter it, and fortunately was just in time to see it pop',
#  '\nafter it, and fortunately was just in time to see it pop do',
#  'ter it, and fortunately was just in time to see it pop down ',
#  ' it, and fortunately was just in time to see it pop down a l',
#  ', and fortunately was just in time to see it pop down a larg',
#  'nd fortunately was just in time to see it pop down a large\r\n',
#  'fortunately was just in time to see it pop down a large\r\nrab',
#  'tunately was just in time to see it pop down a large\r\nrabbit',
#  'ately was just in time to see it pop down a large\r\nrabbit-ho',
#  'ly was just in time to see it pop down a large\r\nrabbit-hole ',
#  'was just in time to see it pop down a large\r\nrabbit-hole und',
#  ' just in time to see it pop down a large\r\nrabbit-hole under ',
#  'st in time to see it pop down a large\r\nrabbit-hole under the',
#  'in time to see it pop down a large\r\nrabbit-hole under the he',
#  'time to see it pop down a large\r\nrabbit-hole under the hedge',
#  'e to see it pop down a large\r\nrabbit-hole under the hedge.\r\n',
#  'o see it pop down a large\r\nrabbit-hole under the hedge.\r\n\r\ni',
#  'ee it pop down a large\r\nrabbit-hole under the hedge.\r\n\r\nin a',
#  'it pop down a large\r\nrabbit-hole under the hedge.\r\n\r\nin anot',
#  'pop down a large\r\nrabbit-hole under the hedge.\r\n\r\nin another',
#  ' down a large\r\nrabbit-hole under the hedge.\r\n\r\nin another mo',
#  'wn a large\r\nrabbit-hole under the hedge.\r\n\r\nin another momen',
#  'a large\r\nrabbit-hole under the hedge.\r\n\r\nin another moment d',
#  'arge\r\nrabbit-hole under the hedge.\r\n\r\nin another moment down',
#  'e\r\nrabbit-hole under the hedge.\r\n\r\nin another moment down we',
#  'rabbit-hole under the hedge.\r\n\r\nin another moment down went ',
#  'bit-hole under the hedge.\r\n\r\nin another moment down went ali',
#  '-hole under the hedge.\r\n\r\nin another moment down went alice ',
#  'le under the hedge.\r\n\r\nin another moment down went alice aft',
# ...
#  'y, and then\r\ndipped suddenly down, so suddenly that alice ha',
#  'and then\r\ndipped suddenly down, so suddenly that alice had n',
#  ' then\r\ndipped suddenly down, so suddenly that alice had not ',
#  'en\r\ndipped suddenly down, so suddenly that alice had not a m',
#  '\ndipped suddenly down, so suddenly that alice had not a mome',
#  'pped suddenly down, so suddenly that alice had not a moment ',
#  'd suddenly down, so suddenly that alice had not a moment to ',
#  'uddenly down, so suddenly that alice had not a moment to thi',
#  'enly down, so suddenly that alice had not a moment to think\r',
#  'y down, so suddenly that alice had not a moment to think\r\nab',
#  'own, so suddenly that alice had not a moment to think\r\nabout',
#  ', so suddenly that alice had not a moment to think\r\nabout st',
#  'o suddenly that alice had not a moment to think\r\nabout stopp',
#  'uddenly that alice had not a moment to think\r\nabout stopping',
#  'enly that alice had not a moment to think\r\nabout stopping he',
#  'y that alice had not a moment to think\r\nabout stopping herse',
#  'hat alice had not a moment to think\r\nabout stopping herself ',
#  ' alice had not a moment to think\r\nabout stopping herself bef',
#  'ice had not a moment to think\r\nabout stopping herself before',
#  ' had not a moment to think\r\nabout stopping herself before sh',
#  'd not a moment to think\r\nabout stopping herself before she f',
#  'ot a moment to think\r\nabout stopping herself before she foun',
#  'a moment to think\r\nabout stopping herself before she found h',
#  'oment to think\r\nabout stopping herself before she found hers',
#  'nt to think\r\nabout stopping herself before she found herself',
#  'to think\r\nabout stopping herself before she found herself fa',
#  'think\r\nabout stopping herself before she found herself falli',
#  'nk\r\nabout stopping herself before she found herself falling ',
#  '\nabout stopping herself before she found herself falling dow',
#  'out stopping herself before she found herself falling down a',
#  ' stopping herself before she found herself falling down a ve',
#  'opping herself before she found herself falling down a very ',
#  'ing herself before she found herself falling down a very dee',
#  ' herself before she found herself falling down a very deep\r\n',
#  'rself before she found herself falling down a very deep\r\nwel',
#  'lf before she found herself falling down a very deep\r\nwell.\r',
#  'before she found herself falling down a very deep\r\nwell.\r\n\r\n',
#  'ore she found herself falling down a very deep\r\nwell.\r\n\r\neit',
#  ' she found herself falling down a very deep\r\nwell.\r\n\r\neither',
#  'e found herself falling down a very deep\r\nwell.\r\n\r\neither th',
#  'ound herself falling down a very deep\r\nwell.\r\n\r\neither the w',
#  'd herself falling down a very deep\r\nwell.\r\n\r\neither the well',
#  'erself falling down a very deep\r\nwell.\r\n\r\neither the well wa',
#  'elf falling down a very deep\r\nwell.\r\n\r\neither the well was v',
#  ' falling down a very deep\r\nwell.\r\n\r\neither the well was very',
#  'lling down a very deep\r\nwell.\r\n\r\neither the well was very de',
#  'ng down a very deep\r\nwell.\r\n\r\neither the well was very deep,',
#  'down a very deep\r\nwell.\r\n\r\neither the well was very deep, or',
#  'n a very deep\r\nwell.\r\n\r\neither the well was very deep, or sh',
#  ' very deep\r\nwell.\r\n\r\neither the well was very deep, or she f',
#  'ry deep\r\nwell.\r\n\r\neither the well was very deep, or she fell',
#  'deep\r\nwell.\r\n\r\neither the well was very deep, or she fell ve',
#  'p\r\nwell.\r\n\r\neither the well was very deep, or she fell very ',
#  'well.\r\n\r\neither the well was very deep, or she fell very slo',
#  'l.\r\n\r\neither the well was very deep, or she fell very slowly',
#  '\n\r\neither the well was very deep, or she fell very slowly, f',
#  'either the well was very deep, or she fell very slowly, for ',
#  'her the well was very deep, or she fell very slowly, for she',
#  ' the well was very deep, or she fell very slowly, for she ha',
#  'e well was very deep, or she fell very slowly, for she had\r\n',
#  'ell was very deep, or she fell very slowly, for she had\r\nple',
#  ' was very deep, or she fell very slowly, for she had\r\nplenty',
#  's very deep, or she fell very slowly, for she had\r\nplenty of',
#  'ery deep, or she fell very slowly, for she had\r\nplenty of ti',
#  ' deep, or she fell very slowly, for she had\r\nplenty of time ',
#  'ep, or she fell very slowly, for she had\r\nplenty of time as ',
#  ' or she fell very slowly, for she had\r\nplenty of time as she',
#  ' she fell very slowly, for she had\r\nplenty of time as she we',
#  'e fell very slowly, for she had\r\nplenty of time as she went ',
#  'ell very slowly, for she had\r\nplenty of time as she went dow',
#  ' very slowly, for she had\r\nplenty of time as she went down t',
#  'ry slowly, for she had\r\nplenty of time as she went down to l',
#  'slowly, for she had\r\nplenty of time as she went down to look',
#  'wly, for she had\r\nplenty of time as she went down to look ab',
#  ', for she had\r\nplenty of time as she went down to look about',
#  'or she had\r\nplenty of time as she went down to look about he',
#  'she had\r\nplenty of time as she went down to look about her a',
#  ' had\r\nplenty of time as she went down to look about her and ',
#  'd\r\nplenty of time as she went down to look about her and to ',
#  'plenty of time as she went down to look about her and to won',
#  'nty of time as she went down to look about her and to wonder',
#  ' of time as she went down to look about her and to wonder wh',
#  ' time as she went down to look about her and to wonder what ',
#  'me as she went down to look about her and to wonder what was',
#  'as she went down to look about her and to wonder what was\r\ng',
#  'she went down to look about her and to wonder what was\r\ngoin',
#  ' went down to look about her and to wonder what was\r\ngoing t',
#  'nt down to look about her and to wonder what was\r\ngoing to h',
#  'down to look about her and to wonder what was\r\ngoing to happ',
#  'n to look about her and to wonder what was\r\ngoing to happen ',
#  'o look about her and to wonder what was\r\ngoing to happen nex',
#  'ook about her and to wonder what was\r\ngoing to happen next. ',
#  ' about her and to wonder what was\r\ngoing to happen next. fir',
#  'out her and to wonder what was\r\ngoing to happen next. first,',
#  ' her and to wonder what was\r\ngoing to happen next. first, sh',
#  'r and to wonder what was\r\ngoing to happen next. first, she t',
#  'nd to wonder what was\r\ngoing to happen next. first, she trie',
#  'to wonder what was\r\ngoing to happen next. first, she tried t',
#  'wonder what was\r\ngoing to happen next. first, she tried to l',
#  'der what was\r\ngoing to happen next. first, she tried to look',
#  ' what was\r\ngoing to happen next. first, she tried to look do',
#  'at was\r\ngoing to happen next. first, she tried to look down ',
#  'was\r\ngoing to happen next. first, she tried to look down and',
#  '\r\ngoing to happen next. first, she tried to look down and ma',
#  'oing to happen next. first, she tried to look down and make ',
#  'g to happen next. first, she tried to look down and make out',
#  'o happen next. first, she tried to look down and make out wh',
#  'appen next. first, she tried to look down and make out what\r',
#  'en next. first, she tried to look down and make out what\r\nsh',
#  'next. first, she tried to look down and make out what\r\nshe w',
#  't. first, she tried to look down and make out what\r\nshe was ',
#  'first, she tried to look down and make out what\r\nshe was com',
#  'st, she tried to look down and make out what\r\nshe was coming',
#  ' she tried to look down and make out what\r\nshe was coming to',
#  'e tried to look down and make out what\r\nshe was coming to, b',
#  'ried to look down and make out what\r\nshe was coming to, but ',
#  'd to look down and make out what\r\nshe was coming to, but it ',
#  'o look down and make out what\r\nshe was coming to, but it was',
#  'ook down and make out what\r\nshe was coming to, but it was to',
#  ' down and make out what\r\nshe was coming to, but it was too d',
#  'wn and make out what\r\nshe was coming to, but it was too dark',
#  'and make out what\r\nshe was coming to, but it was too dark to',
#  ' make out what\r\nshe was coming to, but it was too dark to se',
#  'ke out what\r\nshe was coming to, but it was too dark to see a',
#  'out what\r\nshe was coming to, but it was too dark to see anyt',
#  ' what\r\nshe was coming to, but it was too dark to see anythin',
#  'at\r\nshe was coming to, but it was too dark to see anything; ',
#  '\nshe was coming to, but it was too dark to see anything; the',
#  'e was coming to, but it was too dark to see anything; then s',
#  'as coming to, but it was too dark to see anything; then she\r',
#  'coming to, but it was too dark to see anything; then she\r\nlo',
#  'ing to, but it was too dark to see anything; then she\r\nlooke',
#  ' to, but it was too dark to see anything; then she\r\nlooked a',
#  ', but it was too dark to see anything; then she\r\nlooked at t',
#  'ut it was too dark to see anything; then she\r\nlooked at the ',
#  'it was too dark to see anything; then she\r\nlooked at the sid',
#  'was too dark to see anything; then she\r\nlooked at the sides ',
#  ' too dark to see anything; then she\r\nlooked at the sides of ',
#  'o dark to see anything; then she\r\nlooked at the sides of the',
#  'ark to see anything; then she\r\nlooked at the sides of the we',
#  ' to see anything; then she\r\nlooked at the sides of the well,',
#  ' see anything; then she\r\nlooked at the sides of the well, an',
#  'e anything; then she\r\nlooked at the sides of the well, and n',
#  'nything; then she\r\nlooked at the sides of the well, and noti',
#  'hing; then she\r\nlooked at the sides of the well, and noticed',
#  'g; then she\r\nlooked at the sides of the well, and noticed th',
#  'then she\r\nlooked at the sides of the well, and noticed that ',
#  'n she\r\nlooked at the sides of the well, and noticed that the',
#  'he\r\nlooked at the sides of the well, and noticed that they w',
#  '\nlooked at the sides of the well, and noticed that they were',
#  'oked at the sides of the well, and noticed that they were fi',
#  'd at the sides of the well, and noticed that they were fille',
#  't the sides of the well, and noticed that they were filled w',
#  'he sides of the well, and noticed that they were filled with',
#  'sides of the well, and noticed that they were filled with\r\nc',
#  'es of the well, and noticed that they were filled with\r\ncupb',
#  'of the well, and noticed that they were filled with\r\ncupboar',
#  'the well, and noticed that they were filled with\r\ncupboards ',
#  ' well, and noticed that they were filled with\r\ncupboards and',
#  'll, and noticed that they were filled with\r\ncupboards and bo',
#  ' and noticed that they were filled with\r\ncupboards and book-',
#  'd noticed that they were filled with\r\ncupboards and book-she',
#  'oticed that they were filled with\r\ncupboards and book-shelve',
#  'ced that they were filled with\r\ncupboards and book-shelves; ',
#  ' that they were filled with\r\ncupboards and book-shelves; her',
#  'at they were filled with\r\ncupboards and book-shelves; here a',
#  'they were filled with\r\ncupboards and book-shelves; here and ',
#  'y were filled with\r\ncupboards and book-shelves; here and the',
#  'ere filled with\r\ncupboards and book-shelves; here and there ',
#  ' filled with\r\ncupboards and book-shelves; here and there she',
#  'lled with\r\ncupboards and book-shelves; here and there she sa',
#  'd with\r\ncupboards and book-shelves; here and there she saw m',
#  'ith\r\ncupboards and book-shelves; here and there she saw maps',
#  '\r\ncupboards and book-shelves; here and there she saw maps an',
#  'upboards and book-shelves; here and there she saw maps and p',
#  'oards and book-shelves; here and there she saw maps and pict',
#  'ds and book-shelves; here and there she saw maps and picture',
#  'and book-shelves; here and there she saw maps and pictures\r\n',
#  ' book-shelves; here and there she saw maps and pictures\r\nhun',
#  'ok-shelves; here and there she saw maps and pictures\r\nhung u',
#  'shelves; here and there she saw maps and pictures\r\nhung upon',
#  'lves; here and there she saw maps and pictures\r\nhung upon pe',
#  's; here and there she saw maps and pictures\r\nhung upon pegs.',
#  'here and there she saw maps and pictures\r\nhung upon pegs. sh',
#  'e and there she saw maps and pictures\r\nhung upon pegs. she t',
#  'nd there she saw maps and pictures\r\nhung upon pegs. she took',
#  'there she saw maps and pictures\r\nhung upon pegs. she took do',
#  're she saw maps and pictures\r\nhung upon pegs. she took down ',
#  'she saw maps and pictures\r\nhung upon pegs. she took down a j',
#  ' saw maps and pictures\r\nhung upon pegs. she took down a jar ',
#  'w maps and pictures\r\nhung upon pegs. she took down a jar fro',
#  'aps and pictures\r\nhung upon pegs. she took down a jar from o',
#  ' and pictures\r\nhung upon pegs. she took down a jar from one ',
#  'd pictures\r\nhung upon pegs. she took down a jar from one of ',
#  'ictures\r\nhung upon pegs. she took down a jar from one of the',
#  'ures\r\nhung upon pegs. she took down a jar from one of the sh',
#  's\r\nhung upon pegs. she took down a jar from one of the shelv',
#  'hung upon pegs. she took down a jar from one of the shelves ',
#  'g upon pegs. she took down a jar from one of the shelves as\r',
#  'pon pegs. she took down a jar from one of the shelves as\r\nsh',
#  ' pegs. she took down a jar from one of the shelves as\r\nshe p',
#  'gs. she took down a jar from one of the shelves as\r\nshe pass',
#  ' she took down a jar from one of the shelves as\r\nshe passed;',
#  'e took down a jar from one of the shelves as\r\nshe passed; it',
#  'ook down a jar from one of the shelves as\r\nshe passed; it wa',
#  ' down a jar from one of the shelves as\r\nshe passed; it was l',
#  'wn a jar from one of the shelves as\r\nshe passed; it was labe',
#  'a jar from one of the shelves as\r\nshe passed; it was labelle',
#  "ar from one of the shelves as\r\nshe passed; it was labelled '",
#  "from one of the shelves as\r\nshe passed; it was labelled 'ora",
#  "m one of the shelves as\r\nshe passed; it was labelled 'orange",
#  "ne of the shelves as\r\nshe passed; it was labelled 'orange ma",
#  "of the shelves as\r\nshe passed; it was labelled 'orange marma",
#  "the shelves as\r\nshe passed; it was labelled 'orange marmalad",
#  " shelves as\r\nshe passed; it was labelled 'orange marmalade',",
#  "elves as\r\nshe passed; it was labelled 'orange marmalade', bu",
#  "es as\r\nshe passed; it was labelled 'orange marmalade', but t",
#  "as\r\nshe passed; it was labelled 'orange marmalade', but to h",
#  "\nshe passed; it was labelled 'orange marmalade', but to her ",
#  "e passed; it was labelled 'orange marmalade', but to her gre",
#  "assed; it was labelled 'orange marmalade', but to her great\r",
#  "ed; it was labelled 'orange marmalade', but to her great\r\ndi",
#  " it was labelled 'orange marmalade', but to her great\r\ndisap",
#  " was labelled 'orange marmalade', but to her great\r\ndisappoi",
#  "s labelled 'orange marmalade', but to her great\r\ndisappointm",
#  "abelled 'orange marmalade', but to her great\r\ndisappointment",
#  "lled 'orange marmalade', but to her great\r\ndisappointment it",
#  "d 'orange marmalade', but to her great\r\ndisappointment it wa",
#  "orange marmalade', but to her great\r\ndisappointment it was e",
#  "nge marmalade', but to her great\r\ndisappointment it was empt",
#  " marmalade', but to her great\r\ndisappointment it was empty: ",
#  "rmalade', but to her great\r\ndisappointment it was empty: she",
#  "lade', but to her great\r\ndisappointment it was empty: she di",
#  "e', but to her great\r\ndisappointment it was empty: she did n",
#  ' but to her great\r\ndisappointment it was empty: she did not ',
#  't to her great\r\ndisappointment it was empty: she did not lik',
#  'o her great\r\ndisappointment it was empty: she did not like t',
#  'er great\r\ndisappointment it was empty: she did not like to d',
#  ...]

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
# model = keras.models.Sequential()
# a=model.get_weights('/content/drive/My Drive/test.pkl')
# a=model.load('/content/drive/My Drive/test.pkl')
# model.load_weights('/content/drive/My Drive/test.pkl')

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
 model.fit(x, y,
              batch_size=128,
              epochs=10)
# Out:
# Epoch 1/10
# 55819/55819 [==============================] - 92s 2ms/step - loss: 2.2586
# Epoch 2/10
# 55819/55819 [==============================] - 90s 2ms/step - loss: 1.7501
# Epoch 3/10
# 55819/55819 [==============================] - 95s 2ms/step - loss: 1.5674
# Epoch 4/10
# 55819/55819 [==============================] - 91s 2ms/step - loss: 1.4503
# Epoch 5/10
# 55819/55819 [==============================] - 91s 2ms/step - loss: 1.3638
# Epoch 6/10
# 55819/55819 [==============================] - 91s 2ms/step - loss: 1.3014
# Epoch 7/10
# 55819/55819 [==============================] - 91s 2ms/step - loss: 1.2537
# Epoch 8/10
# 55819/55819 [==============================] - 91s 2ms/step - loss: 1.2127
# Epoch 9/10
# 55819/55819 [==============================] - 91s 2ms/step - loss: 1.1802
# Epoch 10/10
# 55819/55819 [==============================] - 96s 2ms/step - loss: 1.1562

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.

# %% [markdown]
# ## **Saving model**

# %%
model.save('/content/drive/My Drive/lord_of_rings_1.hdf5')

# %% [markdown]
# ## **Loading model**

# %%
# keras.models.load_model('/content/drive/My Drive/lord_of_rings_1.hdf5')

# %% [markdown]
# # **Testing**

# %%
import random
import sys

# Select a text seed at random
start_index = random.randint(0, len(text) - maxlen - 1)
generated_text = text[start_index: start_index + maxlen]
print('--- Generating with seed: "' + generated_text + '"')

for temperature in [0.2, 0.5, 1.0, 1.2]:
    print('------ temperature:', temperature)
    sys.stdout.write(generated_text)

    # We generate 400 characters
    for i in range(400):
        sampled = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(generated_text):
            sampled[0, t, char_indices[char]] = 1.

        preds = model.predict(sampled, verbose=0)[0]
        next_index = sample(preds, temperature)
        next_char = chars[next_index]

        generated_text += next_char
        generated_text = generated_text[1:]

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# --- Generating with seed: " first
# saw the white rabbit. she was a little nervous about"
# ------ temperature: 0.2
#  first
# saw the white rabbit. she was a little nervous about in a project gutenberg-tm ebedied to herself thing you cave pait the party while all the tire, and said to herself with the project gutenberg-tm electronic work is a different the puppy again, and the march hare the player alice, and the march hare the partiences to say the project gutenberg-tm electronic work is a project gutenberg-tm electronic work is a different the paragran. 'it was a rabbit
# ------ temperature: 0.5
#
#
#
#
# 'what did the march hare till she was a mind noticed in the permaps a white rable the rabbit at alice, she caule hope all the repeat of the spoke all the table was work
# ------ temperature: 1.0
#
#
#
#
#
#
#
#
#
# inthe rope addetiel' as alm
# ------ temperature: 1.2
#  then would ath thenw, you ever
#
#
#
#
#
#
#
#
#
#
# great dreap, and wet. 'i'm litten but quivell :y wings!"ere's they doing tame that are after the looked ut, about throwbing!' swait the much .ould wit

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
