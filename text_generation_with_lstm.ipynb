# %% [markdown]
# <a href="https://colab.research.google.com/github/abulhasanat/NLP-Experiments/blob/master/text_generation_with_lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
keras.__version__
# Out:
# '2.3.1'

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import keras
import numpy as np

# %%
path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 600893

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
# model = keras.models.Sequential()
# a=model.get_weights('/content/drive/My Drive/test.pkl')
# a=model.load('/content/drive/My Drive/test.pkl')
# model.load_weights('/content/drive/My Drive/test.pkl')

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 347s 2ms/step - loss: 1.9467
# --- Generating with seed: "slander, suspicion, expulsion, and even
# worse consequences o"
# ------ temperature: 0.2
# slander, suspicion, expulsion, and even
# worse consequences of the sense the senting to the senting to the senticated the some the senting the senting the sensity and the sensity and the still he who he soul and the sense the sense the sense the preciated to the soul the religious and the strage the senticated to it is the sense the some the sense the sensity and the stranger to the sense of the decient in the sense the stander to the senting the sensity an
# ------ temperature: 0.5
# cient in the sense the stander to the senting the sensity and conceine of every self-consited there is as the secul a conscy to the discenture in the self-doneces for the to it is
# the secially we pretict the something the were like the man here in all they somether from religious and regarded to the spect to the suble the regard of the because the remore will the religions it is it is he does to the contrant to religion of the indivent and the stood, the p
# ------ temperature: 1.0
# he contrant to religion of the indivent and the stood, the prefine its plectartancation,  not is taste of nemesives ahe preceatt. would philomon boon the notured of romen, inteener
# paring towable socuiged
# poss it"ipover belfever the methural couned not relegrie thac ratkinity cerranity. teatm for forture upon holoun werble
# if-ever he scceitic a will will doon and conceinenxire farse, of eess manler: man
# inckaded ha"? and the mi!
# pact and it tomenys feelsed
# ------ temperature: 1.2
# r: man
# inckaded ha"? and the mi!
# pact and it tomenys feelsed cfultedher sjulve,  , vake
# tetesn, whoeven the inting toats nor the stoflty; dogill atel pution the  manyes, is
# fould free treat
# rith they comp not puria izbigions as itstendent man iffflened the philozration". they spe such mock prisung that bethingety filally sep bwe viloday the
# utmer ay
# themr..
#
# "m an led nature for
# youl itt very subeluse do: an even at "eess epolly eag not pirably their aper
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 330s 2ms/step - loss: 1.6092
# --- Generating with seed: "his party: for beside
# him stood one of his old associates wh"
# ------ temperature: 0.2
# his party: for beside
# him stood one of his old associates which the superfication of the same to the farth and string the same stand of the man in the same the soul of the same soul of the soul of the same and strength and strength of the extent and string and the and so not the farth and string of the superfiction of the sense of the same such and so the superfort of the same stand of the same the man in the soul and so man in the same the soul and string
# ------ temperature: 0.5
# e man in the soul and so man in the same the soul and string the
# sense is sacrifice his own present wind and gurment away feeling to "the sorie the and strength of the will the
# sense of the and find have mankind superflusive such the forent to the sure of the such and string and stands of the free dream care a have has the same so not and the dispose sees and soul the man for the not and so the some as a seek the serficiate of such and things a man to of t
# ------ temperature: 1.0
# me as a seek the serficiate of such and things a man to of the
# sorreation to not sulferly exuloutar2
# more enoter is a disposes so religions ( the overtus so not
# dim understanded else docgured it mightconnession of schenowor is dighture the mented the
# evil by sa)n for thus which
# to free lighteness of
# turn a fature of
# the the, part, there his own sudking rustance so
# no delimption mid-to through when.
#  our
# forext the degrend soted of this
#
# whome this confusi
# ------ temperature: 1.2
# .
#  our
# forext the degrend soted of this
#
# whome this confusivencesta-be
# things, uhis can vorially blec?" and god of ond
# divene the boligs, the time and lloodingings consadvation aithing inficled perhapination.
# with
# that inserledflund tamese wit it himself gille systemxtly tnaith
# unwould seculf, anditysies.."
# to geen will progeep
# but huff
# men the las the pacholagesnodous and stained wyuthyment, origin evasuctial magily german over moness?"
# ripois
# by reliwer
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 332s 2ms/step - loss: 1.5259
# --- Generating with seed: "long with a single one has not been pushed to its
# furthest e"
# ------ temperature: 0.2
# long with a single one has not been pushed to its
# furthest every the strength as a self and such and and the strong and because of the self-for the decession and the self and the strong of the self self self such a proper and self something of the strongle and soul and strong and self and the soul of the strength and such a far the strength and and the self self-constitute of the strength and soul and some the senses the feeling of the self sees to the con
# ------ temperature: 0.5
#  and some the senses the feeling of the self sees to the condection of a degree for every interered of the
# strength of the spirit, a sure the deally one of the readily of the coult some stands man in the rebless and saint to
# priponess of the same to the seem of the world and acts of a feelingment and the strength of the german spering of the fire of the recollension of the man is soul as the such to him as an and reading, the strong as as the bring at pres
# ------ temperature: 1.0
# to him as an and reading, the strong as as the bring at pressess a the almery which this gyself himself and litterity, and to before as no though groty a beatulity of the putener hand which and make the realing as such at impulsety-philosopher!
#
# ve--e outs been enorgance of curtury follow enemeets from the procroper, all, for wonder, becquev=ule for the most stakest,
# let of once as a different even conted the raghtany: but it is
# wish tlingumination as to t
# ------ temperature: 1.2
# n conted the raghtany: but it is
# wish tlingumination as to the moustlake mindneity cause, andorpale duff
# it
# s readine are ifcereed schem and sens and health tro
# dary, rihh are poeteet to schopenkeves not good thereby b new tatom or were of connects eoos but , themfal
# come.
# yguque and rearly ohp
# spifitle of
# mystely a 'make
# serown to
# his rekec "to
# lo) from an sidicaling, socie
# genaual
# man, nam letely presence, fect action is not bleever strect without sochar
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 330s 2ms/step - loss: 1.4778
# --- Generating with seed: "such immodest
# gross errors--as, for instance, have been fost"
# ------ temperature: 0.2
# such immodest
# gross errors--as, for instance, have been fosterness of the respections of the sense the conceaded the profound and concealed and the religious desire and the discontempt of the and the profound ending the sense of the sense and and the desires and the comprehensive in the sense and the sense of the fact of the profounder the distrustful in the sense the sense of the comparis and the same and the instranger, and the sense of the distrust of t
# ------ temperature: 0.5
#  same and the instranger, and the sense of the distrust of the say in the and the finally and and here of the instranger, it is here and affornt to any in something, in moral too, in the problem of the moral protection beling of the strangent and cultive to regard the free spiritual and actrious man, and the masterilo; and the man is a thing promice the man in the sense for the religious, and the capens one desires and different or and something distrused
# ------ temperature: 1.0
# capens one desires and different or and something distrused provords of the divinct, as grelk original corled--inclimasi-man a panifourd of clans that the sewicialty and really and interpretationals desendionsty al-o.=--the times;-recall of the
# pare have desirable.
# they precisely the lises will cont.ty is here socjoy and indicate and thinkequare
# hand the
# entailed; po shact that, i, human proves trable or many teppoisming and perplestt is despostial, sow.
# t
# ------ temperature: 1.2
# able or many teppoisming and perplestt is despostial, sow.
# this stone laugh the bother, his
# prayopined. mis growtonocy thse? what; but" then
# thon for them, become, with foum, they have there one for, at that, therepjenly. with ooder circementsuny is
# geteer tapalizious, have histonizoms! nece? if renderup", as istenme, chrsioms have grown on oon leasser, ffend
# must to all those uses. i  n for
# oft feeler tings; i popu, ld
# the prodediunst--isafderine as eveno
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 330s 2ms/step - loss: 1.4492
# --- Generating with seed: "ed forgetfulness as a sentinel at the portal of the temple o"
# ------ temperature: 0.2
# ed forgetfulness as a sentinel at the portal of the temple of the sense of the sense and the sense and sense of the sense and self-contempt of the sense of the state of the intellige of the action of the sense of the conclusion of the sense of the sense and the man in the enturen of the conceived to the conclusion of the conceived the intellect of the sense of the contempt of the conclusion of the the conceived to the conduct of the sense of the sense of t
# ------ temperature: 0.5
#  the conceived to the conduct of the sense of the sense of the extent, of the are a conduct of all the enough that the south of the general place of the high entinece, who in the grantions, and like the entire all the conclusions, and the periliness in the could be able to the fact in the sublime really the always of the general personally in the same tended and alwor of in the conditions of the promise of control the believe of the sense of the happiness
# ------ temperature: 1.0
# romise of control the believe of the sense of the happiness woudned; it is stois else, ressing on the telline-to man-fiverpound among actions,
# here one most time. tas the the farconed him oppations and proofs we knows, in evenge, that. the hable ar habj be per-obking twone
# along metoods undermandad into a comparis withrough; and say no
# therein
# in your nature, and will a latert as thear deve. upon the fundamentally its own, nor from mens, which "we habd ast
# ------ temperature: 1.2
# the fundamentally its own, nor from mens, which "we habd asthece. it ceds mode rearers ha
# crueltybod most alfory from vitlo putsedmination. and us enrot
# of what this subject of anew
# enture, pull2king wither mame against, garless.
# mandife, no aparatiesly, that brodounlugely in lictno's beliugn finder requires, this characternst utility of we feith of tobert him of part of the world, what philologys means, recognided ts the spion which bmanay teetarci frasta
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 331s 2ms/step - loss: 1.4266
# --- Generating with seed: "nd often not only contrary, instincts
# and standards of value"
# ------ temperature: 0.2
# nd often not only contrary, instincts
# and standards of values and morality of the same deception of the consciously of the most religion of the subjuctive and the most responsibility of the strength of the most the consciously and so the spirit of the same to a strong the world of the sense and and the spirits of the consciously of the spirits of the result and even the superiority of the spirits of the same the strength and and strong the spirits of the c
# ------ temperature: 0.5
# of the same the strength and and strong the spirits of the controlence of the most result and the present in the spirits of the fact of the conceptional and sunstanday such a servence of humanity and soul of a surtic and a strong to the entire of the live of the strength and also his heres the render the variety, and and he and the trought of the world in rest
# one must and so that the acts the religion where one philosopher and descent to the are the prove
# ------ temperature: 1.0
# igion where one philosopher and descent to the are the proved life they do in advantage type cle by a kind the hearth: it responsibility--or him
# imprompress of a do the development, the greater--is a seried prined how he" very
# hard, and wishangecity and bothssiby and pride by the part to
# certain "toous defect in "spirity for it and most consequence may
# improns"fortal could and can to sciecle, "begnet.
# consciousness of same hrausary bely ligs of curilitial
# ------ temperature: 1.2
# net.
# consciousness of same hrausary bely ligs of curilitial prised if musiczly dnight oped a ternt, "it
# woll.
# them".
# whe matter, faithors, ar"
# mistime he rulance impro" metaphysuck and
# devolinc,
# speadence ty
# orgis over our knding by a ther effected,--serst obery iveds, in primiting con?usaline in we has and tro examsomate. russonly bald., he will suemence not is accusificen, alasrreating undegr
# ppoliming meachen to be man bit instinct s: unstsrsity, too pa
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 331s 2ms/step - loss: 1.4072
# --- Generating with seed: "belief troubles [the believer],
# occasions pain, therefore it"
# ------ temperature: 0.2
# belief troubles [the believer],
# occasions pain, therefore it is all the instincts and self-kind to the present the really to the standards the conscience of the acts of the delicate and the present the power of the sense of the endured the means of the saint and the most self-contempt of the sense and into the religious and the entire and the present man in the state of the instinction and the perhat power and standards them the present the sense of the se
# ------ temperature: 0.5
# hat power and standards them the present the sense of the sentiments of the god the other and from a still the deceives there
# more be comparism of the greatest and instance, was not them wishes a poneublate and seems to their philosophers, which better to the present of the german perhapl" man in the sense is to seem of the expression and precisely the mother of the tantable to the same to organization of view of spirit in the german and this seem of the o
# ------ temperature: 1.0
# ation of view of spirit in the german and this seem of the old eovean without being agnee. which and should is time as he as heares which
# begave
# industr.
#      uslousime for instance aditation;--the pertain, brame e'h in this is higher this course assiousness, it, is matterialters", then, everdounted, which
# for about it condition, ever attintion
# in rule; can
# acts..
#
# 1le, but mistaken denys to fast, or telte degreely for the chemontant are some co
# ------ temperature: 1.2
# ys to fast, or telte degreely for the chemontant are some compreute jereger is mony known,
# not in science conver toict, adbato
# every"ness soo
# is "man of conscientual
# german flaceing, pritsonless the unsfur both, there is syy ood are given and when they are preesentable fortnicates tripatiom, if severmut casegior moupty
# simposied;
#
# vericbleination"--overach ear, they which
# the dogen to
# its lowe, nature our tofear only
# ausloy is
# therene if thes latter, what
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 331s 2ms/step - loss: 1.3933
# --- Generating with seed: "ossible. man sought to become anxious about the state of
# his"
# ------ temperature: 0.2
# ossible. man sought to become anxious about the state of
# his stood and the world and soul of the strong the world and the strong and respect of the strong the most consideration of the spirit and consideration and soul and the conduct the soul of the soul and which an act of the soul and the action and consideration of the strong to be so man in the strength in the spirit of the struggle and contemption of the soul and a man and actions of the souther the
# ------ temperature: 0.5
# mption of the soul and a man and actions of the souther the comparison in the action through the man and world of the feelings which it like the finer ground, the experience of the consideration, are themselves of the world to merely good all divine that religious and ever it is and talation and attain and the one friends. the string and consideration of the latter and ordinary morality action and one must be should be good one and discostes, and will stor
# ------ temperature: 1.0
#  one must be should be good one and discostes, and will storn, feely man rothom as europed, and ro.ving
# and good bad to appear towards untrivine thus, and wilicied which is for the fathers in their did it us acts vollence for it can reallent-place
# a mag you on and very shall
# volsinus, them now indiests mellightic pul paragious really we i have been
# cacalea, of still yesply him , inemmensatie to very europeans of his
# irready even and sacrificed bbenge stitt
# ------ temperature: 1.2
# ry europeans of his
# irready even and sacrificed bbenge stitt in the word men by mousr incliratable holding a
# vreag or plucks us
# through is hystrahess anything magtlyy
# over in his powar
# dow time a most my. the rangunatilie, ethic-sting delight of ppelier inserspeneness:
# doences of the same other cringitics--in anaccels-asa
# every ewapter--friends, to how meres peopla,ience wso as alsooje; just inflryun, these make
# to periencely more that there
# say, its caars
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 331s 2ms/step - loss: 1.3815
# --- Generating with seed: "as belonged to the soporific
# appliances--and that "virtue," "
# ------ temperature: 0.2
# as belonged to the soporific
# appliances--and that "virtue," in the sense in the same the same to the same as some to the same and the sense the german morality of the souls, and the sense the problem of the same discentent and the strength and some to the same disposition of the superitic the fact the discourse in the problems of the same problems of the same seems the sense in the sense in the same to the same and the such to the same sense the conscience
# ------ temperature: 0.5
# me to the same and the such to the same sense the conscience and souls, where it has not come
# modesf, the consequences of the strength and in the world into can one does not can not with any here with the religion of the strength of the world and conscience to the most discessation of the words
# the delicate and the act for the superitic of the state of the belief in the deliving of the same been delight of the case of the most this some philosopher are for
# ------ temperature: 1.0
# elight of the case of the most this some philosopher are form, but does not darban amider life that it something from these father opinion is
# a nought--such the"
# one german domind with instance, who are pbiest swhold lack
# of
# resultent--religion words! somproble him with such periousne,
# entinily, the stioking, not
# exactdwination, hownyor, to failic bring a newishefulnessing and
# ose
# different thromlowing regarding
# mlo
# acts
# of ondsess, fiver subtlry
# can stopi
# ------ temperature: 1.2
# owing regarding
# mlo
# acts
# of ondsess, fiver subtlry
# can stopinetras; for our necessary wandd by the begloums eevel has necesser dotultum emerbeidness to one
#  and
# chablism, it is houlation of , more stotely, squpidity is its feelings bad
# the anyone; but or: "    throwsty
# i way of a pliwa
# (one durongeully kind experience, at historically
# danker.
#
# 11ly she is within
# manne!--like immensed and
# glarr of the samal progradation co mperian coarses. so in germans tir
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 330s 2ms/step - loss: 1.3721
# --- Generating with seed: " it so severed and so
# antithetical that it denies the possib"
# ------ temperature: 0.2
#  it so severed and so
# antithetical that it denies the possible in the fact the conser self-condition of the strength in the sense of the more strong the strength of the strength of the same the sense of the sense of the sense of the man who is to the more of the protection of the consequently the senses and the existence of the more string and the more and the strength of the strength and such the strong the conduct of the senses the desire of the act and
# ------ temperature: 0.5
#  strong the conduct of the senses the desire of the act and belong elevation, as a world must be had to be unseriously that what does how to ranks, and a do not consede of the desire self-same superficial self-responsibility, and passions of its more of the same the cold be reading to the fact through ye catholism of such treater fallen speaks of the sense, the valuations of the deceptions, and he home the great defined the own, after one for the happiness
# ------ temperature: 1.0
#  home the great defined the own, after one for the happiness to a peacely, then life in questions, it was to which
# ? "were slill"--amouthrisoms" artists
# can consequently let it were a long opinion willing
# harking hard accessport a hable of heoping woman has atrain it.w-e
# ary importanises hather--while christianing existence threre, as such "exertanding as only become
# opposed ruct, and of "in greek was nelection of mankind," that themselves, the being any,
# ------ temperature: 1.2
#  was nelection of mankind," that themselves, the being any, of whichsay do, shair: "co-letred the brusefortiness of  grought peight divine himself as to -what severy?
# thus
# constramanes, it is it who retirca,eywhed wosital pletary of it all impistes struged a very the english his subject, he more habit thereby, of involuntary peoples itno, he wholly happin i aquel of perhaps, is never naplaming
# "telse foring
# justiced (because ahe mame:s even of stopictism w
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 333s 2ms/step - loss: 1.3643
# --- Generating with seed: "having the advantage; the more
# select, more refined, more un"
# ------ temperature: 0.2
# having the advantage; the more
# select, more refined, more understanding to the sentences and condition of the sentences to the faculties of the superior and the conscience of the still subtle the sentiment of the senses the sentences and the sentence of the sentence and the same time to the streng of the superior and conscious of the state of the sentences of the same time the senses to the sentences of the sentences of the sentences and the fact that the
# ------ temperature: 0.5
# ces of the sentences of the sentences and the fact that the same best because of the beautiful
# indelinity of a sentiment and sentiments of the store and superior and superior, in the delight to the breater of the superior, the compares to can be enough to an artain and remands of the incline and the deterioral and right than and there one feel prevails of the something in god are only and story. the subtle of the strength and art of the best to the same so
# ------ temperature: 1.0
# he subtle of the strength and art of the best to the same sometin them of superious manicain, and but have himself--for the problem of place th the honouramento toldet of christianity: operative
# and detaritra, on
#
# find kype the "formert
# dangerous by with trushs of the valuem"! it is seeh
# in any ont do an
# are reason-sim than in us in interersome and happyosity than it? with art tenedgens arrangeful, as ky," heodly, of "the commandime is hgreas asity is it a
# ------ temperature: 1.2
# , as ky," heodly, of "the commandime is hgreas asity is it al no brews far is to peimated, if
# a truth,
# scrinse quieviding," is mea uncertanw cannot
# cy
# womend, and formation, stopeful,
# "iher regular much, one with it, included, uncame times by the purpose, pwomoarary more. ethigh who conty rogrousen? then primirach natury
# and
# : ).
#       ne of bering compithesm, and livituous lipetuan woman not orlowinom that
# in pleace but least fanthriard furitory ofs anew
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 334s 2ms/step - loss: 1.3564
# --- Generating with seed: "ll finally be lacking altogether, or they
# will suffer inward"
# ------ temperature: 0.2
# ll finally be lacking altogether, or they
# will suffer inward and the condition of the delicate of the really the condition of the religious and soul is a delicate the same to the look the same to the sense of the delicate of the man there is a soul of the contradyness of the really the sense and sense in the delicate of the desire the man and every double and consideration of the really the case of the delicate of the world in the condition of the command
# ------ temperature: 0.5
# f the delicate of the world in the condition of the command presence of a noble
# desires, the really the discernt and really and how the best one of the moral yesering of their seccious which we conceive of the more the
# servileful and course of the moral general intellectually that thereby which heart of the misunderstand something
# by the
# deach the whole the case of the discernt and the same could have attained to himself whether the "free same distance, as
# ------ temperature: 1.0
# have attained to himself whether the "free same distance, as "ordi" of bliess.
#
#       known, what a
# state sincially a ideal to philologimatim allujueny in manievad.--the fercomen refreel the,
# and in hisc;epard; before the dough in adventurant theist itself, as to lictrgidee thereof-lard has solear only himself than to noble than strength and indifined called by
# senfiesegbe, meash.
# .
#
#
#
#
# 34
#
# =close
# much greate of astension the jessible whosen,
# of god centur
# ------ temperature: 1.2
#
# much greate of astension the jessible whosen,
# of god centuriex
# and like; --n certain thround.--esceteriniousnable exceptioned again that oonc? the
# theold
# religious in which
# evilful slaving mycreedied in"unne" to
# the mosterst
# min, itself, tankhis, of theirt of all they
# prevolbility) of error, induced that therewallfl-d.
#
# bode that their autonabees, fact),--assd-polnons of it;ulous. the rashes: he is lively cintured
# to fould be judge of them. with tme
# rob
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 331s 2ms/step - loss: 1.3502
# --- Generating with seed: "pendent
# upon what his opinion of others is and their opinion"
# ------ temperature: 0.2
# pendent
# upon what his opinion of others is and their opinion of the same temporaring the sense of the sense of the second the sense of the same the same tempo of the sense of the sense of the sense and from the sense of the sense of the sense of the sense of the second in the same tempo of the fact to the father of the sense of the world and the sense of the same the suffer the sense of the sense of the sense of the sense of the same and the second and the
# ------ temperature: 0.5
# of the sense of the sense of the same and the second and the desire of the sense and this must a long and incapacity of its feeling of the sense of the sense the rearely or survive, and in the best one is an absolutely regarded. the thought to any religion of the suffer the heart to be unthoust to a sorility to be sure, and the same sense of the really
# even and bit that the problem of the incluation and strong and the sense of the instincts and such an ext
# ------ temperature: 1.0
# on and strong and the sense of the instincts and such an extracredite,
# exceptional pposes that all the forming of the stars own
# labegen women--comportoffer
# gladually putes, our
# wishalty. then free worte
# attaily intellictiscant.
#
#      for he loticious,
#
# tking attemousury of judgment--i "know more, how communicar, the peculiar
# generations, and
# and bad
# it certain sistic itceou1s; and this men, personage.
#
# 1le it is one was new consideration of the my roation
# ------ temperature: 1.2
# age.
#
# 1le it is one was new consideration of the my roation to
# enlightency withroque europe--is learnnts even their
# questions of edqurom that the
# setation for than the
# eurshed aloud has afteryioncrilogave land. become
# opinion of
# cardonatical divinicied betrecohrs ""well short, devistionalm what
# cat rath for the interend comesicy besoundy mind to breaks his own
# weark, the
# limated--begnounds totjere, evheem cooker of life: ue that artejuring sodged persone!
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 331s 2ms/step - loss: 1.3444
# --- Generating with seed: "ndency of the mysterious labour of their souls was to prepar"
# ------ temperature: 0.2
# ndency of the mysterious labour of their souls was to preparate and soul and in the same to the same to the same to the fathers of the sense of the same to the same of the soul and so that the same to the same to the same to the sense of the delivily and the same to the sense of the same to the same to the probably for the same to the same and the present to the sense of the most subtle and soul and every distorted the same trough and the sense of the sens
# ------ temperature: 0.5
# nd every distorted the same trough and the sense of the sense of the spirit and constitute the every cause is can not seems to the south, for the fathers, who have been such a not the instructive himself to the sense of the sacrificent to him who in the ears upon the able to least to himself to be soverce. the doubt that the preciating and disposition and more stronging and powerful of the highest and most intervated the fact that is not present to be its
# ------ temperature: 1.0
#  and most intervated the fact that is not present to be its refore" a perfectness sextivian among thodeble, or that the way and causei" are belief i considered to rithes of being of a interlohen its reven for feelingsf of its faith of the
# sense in refine rebilical principar-word imlistle and subtle for which there is its dispincts. "for the soutness. as books. at least freedom aid form of
# a sun himself will politic. how to lapthge the kind is necessititule
# ------ temperature: 1.2
# mself will politic. how to lapthge the kind is necessititule: it in yes po, in a bypened firsting of continualty for inthining finefly
# greatadian of the quelists for the good cases, for him is ca-criture thrilless, wismor, in itilitaaveven them
# merists it in his eventured fot it stills,
# whatever conseptizent? it. what nlacking, who
# doges is al equald agcanic more
# and -event say gmatin
# my fact thereby value to "the incritic his avi"thing makes homing that t
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 333s 2ms/step - loss: 1.3400
# --- Generating with seed: "lly
# constituted souls, is in fact, the rule: it is dreadful "
# ------ temperature: 0.2
# lly
# constituted souls, is in fact, the rule: it is dreadful of the spirit of the spirit and some to the same to the world and such a sort of the spirit of the play the spirit to the fact that the problem of the superiority of the spirit to be sublime and the spirit and the more of the spirit and the world of the spirit when the spirit and the spirit and comparison and and the fact that the same to the same to the same temporary fact that the same time to b
# ------ temperature: 0.5
#  the same to the same temporary fact that the same time to be hands what all the common. the conscience of worth and enough species of love of the contemptions in the belief in the decier and much as the gratitude of the some the art of the from the some the out of the same of the strengther, and said whole lower so true, to nowadays are in the same grateful defendent of society of the fact, the responsibility and fatter of the trained and and the constrai
# ------ temperature: 1.0
# esponsibility and fatter of the trained and and the constrainat he the books all the man of preculation
# than the crrecomwing in orhers even toural
# gal hard in and
# handlers, not atheises books of worses--whoever me! as -woman bour music. and be addests aoked be fever
# na thing and in the europea in the states together, which cretame at the eyesty, it as a mist will opportune of much to past creaiated inex orkning
# , themselves have his feet su.
# e=stible and s
# ------ temperature: 1.2
# d inex orkning
# , themselves have his feet su.
# e=stible and sensust with sufficity worldily felt has
# beyond to be broughfaling, to aethy sprivizes bor-thees prepast, induced. hecharmon--or lazzeg. just them have feants can
# chise-scondinuen unselfly wondery of moral
# churages ruling,--the wongred baws.t conlected us became over
# raceed or, self-lhers whein, beydominar vorvabilicsment, condition
# an a higher in cpossing
# inones to concerningst of the ajoagle so w
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 335s 2ms/step - loss: 1.3343
# --- Generating with seed: "and stretch its limbs, and find us too hard, and
# would fain "
# ------ temperature: 0.2
# and stretch its limbs, and find us too hard, and
# would fain and everything with the fact that is a soul in the same contemnable of the way and the same and with a man in the problem of the fact that is a problem of the artist the fact that is a moral religion that the contempt of the world and art and strength and the will and distinguished and the warin and the problem of the sense that the strength and with a man in the sense of a man and the contempt an
# ------ temperature: 0.5
# gth and with a man in the sense of a man and the contempt and one must be good age are soul and contradiction and experiences, and in the act of the condition because we know the religion of the man in the general interbred believe that the easing also are probably for the world of the individual" is an extravence, and which one will that is not the progress, or is in the wellary were will on reliction that an action of a destroy is little evolution of the
# ------ temperature: 1.0
# ction that an action of a destroy is little evolution of the resserine antists tro"g"--that is not fact, and they are acalue of compoten
# are of genius for yothial": is to
# , for our labount digh_ous eapy of examples to extentness of victic those and into in the genera-degrans a discourse
# spirits, even who weadin of habliness
# of mankind of egoism to terupoun. those how , as taikes rexprestry, lose all
# enviradity of psychological
# has now, that
# as cravent, be
# ------ temperature: 1.2
# all
# enviradity of psychological
# has now, that
# as cravent, because we -among for oneymans.=--and strong
# to, un very gut" ex
#     our trough day arer attide of lapting conoint before, noughamines art to dee willd arately, and aupoffi: predorojuitarical, beitt, and still deterecte:
# as condist. so that is now their motives of christicition of re withour on hig-grotest of
# this of disguist of aly barming tves known.--so, thought: midalism-bade. it is
# perpetion--w
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 335s 2ms/step - loss: 1.3288
# --- Generating with seed: "tedly!" replied the other old patriot
# vehemently, "otherwise"
# ------ temperature: 0.2
# tedly!" replied the other old patriot
# vehemently, "otherwise and the man is a soul and all the fact of the man is the man is not the same and the moral former and the man still as the same the same the former and the moral variety of the more schopenhauer of the moral presential the spirits of the moral presentice of the man is a man is not the fact of the sould and the constitutes the senses and the spirits and the fact that the fact of the soul of the sp
# ------ temperature: 0.5
# the spirits and the fact that the fact of the soul of the spirits of which the account and is into him of the moralities and every and the prefurt to the prograin the constant and with the belief in the circumstances for the presentice of the
# harm as our god that the soul and it is the german sense has been the belief that is a person of the enliever--as the heaven of the disclaused and most morality even to men is not in the masters of the deeper of the m
# ------ temperature: 1.0
# ity even to men is not in the masters of the deeper of the modawactial. fell spends to be son: in the
# christianity hay convias to low pritrieachy mea hard very weaker; the runtag! one any obey"--also luppene for all the dreadflical preciusts oppress and
# starked incerest because marlfiness itself, ye free spirits hid-sidence in mankind
# with admitation which only what
# has not even in order that his by thit degrees" and moral physiousm these perception in pol
# ------ temperature: 1.2
# by thit degrees" and moral physiousm these perception in pol=x!inus harm
# his folly as enough that
# judgenc,
# necessive
# truen) stregveran adoutade-uppour handly out in first more
# pertuotive; to had renunaled in the goest and some heapy should us--alurimike soul it for : "own use the "dution as avorbe," that man for thoughts of ciosed i will the out-lider reasiny, good, with intemply are harm and recertles--from the hareman?--the midhal":
# "a d respist. he im--
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 332s 2ms/step - loss: 1.3255
# --- Generating with seed: " them that
# the slave-insurrection in morals commences.
#
# 196."
# ------ temperature: 0.2
#  them that
# the slave-insurrection in morals commences.
#
# 196. a present to the faith of the same to the world of the soul, they are some thing of the most conception of the same to him who can a sort of the act to the superiority of the fact that the sense of the more and such a freedom the soul, and the same to the spirit in the same to the soul, they will a sense of the spirit of the most suffering of the same to the present to the same to the sense of th
# ------ temperature: 0.5
# ng of the same to the present to the same to the sense of the fasion to authority of the same intervaling to an inwith the higher conscience in the values, one of the depth in the origin that the sensations of the measts to superiority of the expendent, there is they are to concepted a demination of his senses thereby and some destruction of the contempt and profound and the present to the conception and something desire to many into the worst of the man o
# ------ temperature: 1.0
# ion and something desire to many into the worst of the man of the impurels of pretermed but no less a need for such a herenestiw, with the suppority, it is to result unover--recear best, the
# rasions, they ares of the cejuding preted, i europe and conside, such he ploiia hackable judgcent and turn a religious profound
# gramed said of all the german sere of suffected in
# the wick, thereforeng, freth an expliness to eme has and into followally
# things, he s
# supi
# ------ temperature: 1.2
# n expliness to eme has and into followally
# things, he s
# supides therety thereloy, to verafcome canevaltness, would be enormous europhen in suprovierm" is dedu to according timess in the certely as destine,ha
# of grammersite up, talr trant"d
# culture. we we centerel"--the consponss
#  the uniginide." she has de each beights a
# teftr to poisony-mnotters. their-laugh, feelings of expressed who prefash of ple claimly works also renlessgicans when does a choud do no
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 333s 2ms/step - loss: 1.3197
# --- Generating with seed: "lp whatever devilry we have in us:--our disgust at the clums"
# ------ temperature: 0.2
# lp whatever devilry we have in us:--our disgust at the clumsy of the most instinct of the more surming the community and the sense of the man of the standay the english when the way and the manifusa and the present different and the more surprised and the more suffer the present the the conscience of the present distortion of the man and the same the man and the same of the conscience and the present to the sense of the same the world and the world and the
# ------ temperature: 0.5
# ent to the sense of the same the world and the world and the most indismust and contemptionally stand would it has hosest and
# spirit and and and surest of intellicipation to make this contemptional interpretations of prevent to and deception of the valuation of the indication and all there is the world of many present deceive the relations, has a grands souls to himself and the moral was upon himself and constraint something properted the means of surrant
# ------ temperature: 1.0
# elf and constraint something properted the means of surrant much by whish to has here rulely dutys, cataces, and meknev: the hands---whencre more effect whenever heapset of the moreordery of that the woritates--and not for himself are
# meanstandilged
# that an
# a bring--a spander, nor have worfly before him was will be but it nothing haff, one blesity-restroys the most self-co
# tests which had housh learned its pist--to phithely is tested its fath preferating,
# ------ temperature: 1.2
# arned its pist--to phithely is tested its fath preferating, for neverthhings, philosoph, this europe of wenfuele
# will allience and sentiny,"
# this independster into heredical only scence of a m dater, view-the relearles could be ex(gng wifcees,
# and perhaps,  rartin sentiments (to call astaihan--whatever evil  guscand admittomed woman when indeed,
# nakes relive, has higher and
# has it like that leav: their own discipure; will, as a deshapping
# nature, withier
# p
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 332s 2ms/step - loss: 1.3185
# --- Generating with seed: "l the greater need is there of
# that steady continuance of la"
# ------ temperature: 0.2
# l the greater need is there of
# that steady continuance of laws of the profounder and strong themselves to the fact that the present the more souls of the sense of the fact them of the same of the souls of the self-desist themselves to be something of the other world of the fact them and self-desists of the sense and strength of the same and and there is not the sense and self-contrary and contradict of the standard of the self-is the self-destruction of th
# ------ temperature: 0.5
# ct of the standard of the self-is the self-destruction of the made and strange of them, and themselves it is not it all the greates of religion which is not always the enclunism of comparison of the stort, and all the conscience and in the contempt and draw the postrous is not not the desire that the conscience of themselves of the breaks that the interpretation to are therefore, and in the traced to the contrary element of a former strong the higher were
# ------ temperature: 1.0
#  to the contrary element of a former strong the higher were contrult in the attempt haw been possible. i "philosophers claimmens of make who groting self. it is not as there and from those have impasteing themse, what thereby also the persisism""--of must necessness. and he would recopted as something origin). but but-authis presence--by a his hersepples and
# tendency, self-far alities, single and orly attention? type. in them weatiness.
# the more deliration
# ------ temperature: 1.2
# orly attention? type. in them weatiness.
# the more delirations, bring transhadar trings: and if i jodund; small it as one free myin.e even wisher ood for
# efraite-youther as a egod from their magice to trains, art, that shy, of deal generality. malsogiciant" of
# insulfu-raciarily a pray, his man--and
# the most sleains of nopment former at linerris of command
# animals along as would d ascauther-namid: beastations is gairses
# have decides
# and hencefjur interpretat
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 333s 2ms/step - loss: 1.3145
# --- Generating with seed: ", the laws of
# number are wholly inapplicable: such laws are "
# ------ temperature: 0.2
# , the laws of
# number are wholly inapplicable: such laws are in the world of the spirit and man that the sense of the more and concerning to the proper and the will to the contrary with the action of the most desire the most such a man of the contrary the spirit to the most such a distinction to the most present the still not the world and concerning the same the whole spirit to the same the man and success and proves to the same to the world and command an
# ------ temperature: 0.5
# d success and proves to the same to the world and command and thought enough and so in the problem and fundamental religious and badness to real and reverence to what the more interpretation that he will so that has been respect to exprease explossing of the father is an evil with the most far myself by the interpretation is in whole destiny has me greater because the interpretation and contradition
# in the proper, the disposing and fundamental and the huma
# ------ temperature: 1.0
# on
# in the proper, the disposing and fundamental and the human medlow-bydsr; tast? grame of by-harprspologicy mind
# am formsound, not applile and more fall, which supercial, and ). the injures to development, refesired takes stations--and becaused in the more such men eyeinal
# world might the will to be experiments, which carnizbeian---i gally way that became others: for
# inability fairs that man to lose his seem (the onleass a readily mame an
# ared should at p
# ------ temperature: 1.2
# ose his seem (the onleass a readily mame an
# ared should at prestortal. from bre
# imeash all the misaces, to be sentiments, pray pationa from mood, comifri-do than antaches in coninginary to
# the recuunary
# judgment of any that) and greated by "pleamance for inorceptor
# one laughes in mo is also among it apprehent musics means, difficult? at present to reuthward arours am far of "knowledge." a course,
# socially a destruction, and standing caus nrend their a men
# epoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 334s 2ms/step - loss: 1.3107
# --- Generating with seed: "w. both are simply sublimations in which the basic element s"
# ------ temperature: 0.2
# w. both are simply sublimations in which the basic element soulser the sense of the sense of the state and the sense of the sense of the sense of the same time the work of the sense and soulser to the state of the state of the state of the state and soulser conditions of the state of the state of the state of the state of the state of the state of the soul, and the sense of the state of the state of the state of the state of the condition of the state of t
# ------ temperature: 0.5
# of the state of the state of the condition of the state of the self-condition of the person that the general conditions and art of the german period of the fact that he would not a soul to have asprehend and souls--the series with the world to the same time the work of the controlitanic and the expedience of the same time the self-genions of the resistent and for the world of moral power of the more mankind and self-carry worker and hence the harmonism, th
# ------ temperature: 1.0
# re mankind and self-carry worker and hence the harmonism, these permute, thought, as marble, valid lateer itself
# and same morals, lost
# there into shrerseet, whether on the one from controud
# and resire and blaronesty, and the matter through hitherto would again the bicdel"--through hosdopness. grow: ustoives himself the right with an down--withself at praces the dangerous suycact also, can dispredu. they coarsly, however, the time of the deep that anesal of
# ------ temperature: 1.2
# . they coarsly, however, the time of the deep that anesal of the happiness, vious, and only influry -conderedors comorite, decain", aokmold, broks th nonce preferst of the cauls man put ocloloved without use conturbing falsowing. it
# that and
# without maste course and usbable
# of time whether severe,
# requiremeltisonly,
# extent from the christian instinctionly, and he evilyx of this subjectest whencoglerly, hereithing these method! asts--bringing happiness at p
# epoch 23
# Epoch 1/1
# 200278/200278 [==============================] - 333s 2ms/step - loss: 1.3056
# --- Generating with seed: "alousy--ah, they know only too well that it will
# flee from t"
# ------ temperature: 0.2
# alousy--ah, they know only too well that it will
# flee from the same to the man in the strengvented the deceived and soul and the problem of the fact that the sense of the bad and superiority of the man there is a soul in the fact that the same to the same therefrer and soul and superiority of the same thereby and profound and something in the spirit of a soul and something that it seems to an according to the senses and the fact that which is the sense of
# ------ temperature: 0.5
# rding to the senses and the fact that which is the sense of man to an end and according tentantament of the whole make
# the greek believe and the assumed to the strengvent in the sense from the predirection of exposition in the honourandly
# to its the commander than of the hasing the familing of the spirit
# of the consspertion that the same things of the one may sees the favour and sannting and distonce and the spirit of the father and therefree and something
# ------ temperature: 1.0
# ...
# interesting to the here anothers of the sun of
# the soul and desire the soul, the strength to pose nothing the knowledge of the
# "giviness of the se
# ------ temperature: 1.0
# gth to pose nothing the knowledge of the
# "giviness of the seniluous are among english sluvit a bastfen
# occlears called pey of all in whole is at the christianity, even lasthes, under historical prefecce; they have spirit france that is not discover
# as not philosophy
# he had, to uncarriated, art of times of morality in its whole provertys (is.--irreaten: totckes also the science, at the famous superioris to lighter these philosophy
# case for his malacy alteni
# ------ temperature: 1.2
# ioris to lighter these philosophy
# case for his malacy alteniency. wuchom, the distrssness med also the world and
# commondemorely. in all reminacl. reachen tomount, as ildaen, cestless of great quite
# to be
# any
# metaphy in the synthesis or antiquitness
# if all english covery our venence of mirryupe psychologistic are folning "would calurice swarind them all domained: the directed in , the manifungle. to thinkeft therein, on christ in old
# when its eviehic hin im
# epoch 53
# Epoch 1/1
# 200278/200278 [==============================] - 331s 2ms/step - loss: 1.2484
# --- Generating with seed: " convenient, as falsehood entails
# invention, make-believe an"
# ------ temperature: 0.2
#  convenient, as falsehood entails
# invention, make-believe and the fact that the world of the present to the problem for the sense of the great word of the benevolent the commence the morality of the fact that the moral the sense of the present that the world and sensities of the fact that the end of the world of the sense of the sense of the gregred and soul and the powerful and soul and personal and fundamentally and conception of the belief in the morali
# ------ temperature: 0.5
# and fundamentally and conception of the belief in the morality that the sensed there is no longer conceal the beloved our its fest under
# point of the highest refute with them--the conception of mankind, and also the whole as the spirit to be all the disposition that they are even something that we have a ways and perhaps the spirit and sensitious and desider--which the
# individual that a
# science of the men harm and something that one of the other human high
# ------ temperature: 1.0
#  the men harm and something that one of the other human high, democraties who is opinion:--that have to recordent, and how drudness
# even emasion of the esole
# of feoring the idea of their self-commonal endemine our higher than himself of the powerful sility be misches for postear bad never of its
# stran-gurpefulal selflishs, (recipality, who forger considerations is betree and values "said upon to
# exists, which could
# never will, is ascendance and detace, "th
# ------ temperature: 1.2
# xists, which could
# never will, is ascendance and detace, "the refinement for barred of that togetherous
# dealts those gone har, too much decificanted. more , the pride
#  scy even rejures our drape: societ--let us
# ecverfuly wordh" supanatate man wanding promore--thus caromed of impulsed of whose typegre valuable stolv. they ill usial scienceiw,s and rebightfunimms in "sin"
# whend the fects
# is -and compessaromg of long-certaint-like holity and origin in us; by
# epoch 54
# Epoch 1/1
# 200278/200278 [==============================] - 334s 2ms/step - loss: 1.2449
# --- Generating with seed: "t for its object the
# infliction of pain upon others but simp"
# ------ temperature: 0.2
# t for its object the
# infliction of pain upon others but simpless metaphysical and superiority of the proper that the more reality and something in the sense of the same to the moral the spirit of the moral the origin of the strength for the sense of the fact that the state of the strength and something which is not a depth of the same to the strength and soul of the sense of the states that the strength and the moral proper to the proper that the strength
# ------ temperature: 0.5
# rength and the moral proper to the proper that the strength and states and the best and something in whom
# the false" in the conception (nonling with its soul of the proper that in the tentiom of the controld there which we have alefical intalleness
# of the reason to the fearly and long called fingers and interest and caterificently and constant the moral and souls--the thing that the strength of the delicate all the greater and for the manifinom, of the sam
# ------ temperature: 1.0
# e delicate all the greater and for the manifinom, of the same his ideas: something must should he livest misurdent our question, too, the
# rewards experience
# and coming and results of us, and different disturbmoots had to
# talk as
# desiration as even a subtertain equally a pasts provertative divining exhign.
# the
# coars. with the most interest to come an short, it are, is also found thought should become that a values effections abwaingbness, it taking colorhin
# ------ temperature: 1.2
# me that a values effections abwaingbness, it taking colorhing
# much
# wast, and thetcy
# ton
# sfain of no thoring. this isoppect of rachers,
# which, and what
# sought it nature falsets with metaped from us the great long a
# waster.
#
# 131. no longer that one
# relic to
# him his faith of man
# anciently is a desidered. head a
# politic guil an inhar world, invest beure,.. of all reupaation
# it cwided presence of catable inscid, under
# idtelinorous jgiburd edurred the same in
# co
# epoch 55
# Epoch 1/1
# 200278/200278 [==============================] - 331s 2ms/step - loss: 1.2460
# --- Generating with seed: "rity, and elevation
# than a nineteenth-century frenchman coul"
# ------ temperature: 0.2
# rity, and elevation
# than a nineteenth-century frenchman could lack and the spirit of the present the morality of the most proper to the fact of the more and the way and because the same of the more far too longer and some time and the proper to the same and consideration of the states and in the soul of the way and every sensity of the same and the way in the fact of the most property and the spirit and in the most proper to the same will be all the spirit
# ------ temperature: 0.5
# it and in the most proper to the same will be all the spirit to truth of the most refinement for the fatherlar, in the uses and discrutts of a destiny--more even the morality and the best presentes a faith--lands and acts itself
# and attentory in the way in such as even every considered to see which the german sensition of such an ears and miserated by the earth, this consideration of the conditioned to him of the fact of the birder and in the same as a val
# ------ temperature: 1.0
# ed to him of the fact of the birder and in the same as a valuation" and be riture: supposing aed of virce,
# which standing, of our pembeains a times and
# athe"y of saint, and above ald how follow of the moral, quited truth", is palware upon the fundamental will from the german sparate sensation are-too most trike, "i arrange of the
# sapinity for creation of false flainher towardof only of the encaual
# comparation stupid thing of grammental thing and course-mif
# ------ temperature: 1.2
#
# comparation stupid thing of grammental thing and course-miffe; warl"--leayt, a innoullonists; if were then to my significanc"'s words!
#
#
# 1                     fore
# the oftings! how i were
# love from
# with
# antadents theses one cwera. the botive treat', -they are oppreserucriai-resshck" suiredence! well, well behinging have heseard awaken, the unsmabl"-fart beyond, not to incluance, his man backualares, cordse" and
# god-lights--an inhapatical etite, france the
# epoch 56
# Epoch 1/1
# 200278/200278 [==============================] - 336s 2ms/step - loss: 1.2444
# --- Generating with seed: "sity--an evolved and hence, also, a transitory
# necessity--de"
# ------ temperature: 0.2
# sity--an evolved and hence, also, a transitory
# necessity--destrustic and conscience, the spirit to the most presently and spirit and the spirit in the same to the most desires to the same to the present that the same to the same time and speaks which is the consequently something which and the spirit of the moral present seems to the world and the world of the same to the sense of the same to the same to the sense of the same to the strength and sense of t
# ------ temperature: 0.5
# same to the sense of the same to the strength and sense of the best self sense of the position of the misperting of the stood in the last deductive and the more effect which the fact of the world or all the development of a socrate of the respect and presentiment, the world test and still be allower in which they are the questionable something for which he was the part of the spirit of the earth of the greek and whole and experience of the same to himself
# ------ temperature: 1.0
# f the greek and whole and experience of the same to himself to get a
# perhalval. an he has its powerful, mach surprisity, that is take, with and wild, can asceticians
# to home, "another soul, to hands and say, the wace it, and danger himself--that he restmguous onness of his fact, that is last one sheejselim, another spirit become of solitudly as to day be the moral moral spotte. here there, to their rise grow, or an hilocveted by should when
# give an indifie
# ------ temperature: 1.2
# r rise grow, or an hilocveted by should when
# give an indifientless a, amontary desentedness and caint that happens as ope of it, in ple! indeed, the i had troughities thomeous,
# had steme,--i free angualict violia or moral' men they in suspinsing,
# mpush, he can impeducted. they dis-deneary hat, but to some the eventh to rulemen body? (the movenounful with idej i h! no durmman spirit only we have a
# offens intlier and sympathy peopl, for
# the prudenity"-therea
# epoch 57
# Epoch 1/1
# 200278/200278 [==============================] - 330s 2ms/step - loss: 1.2431
# --- Generating with seed: "ducation and culture
# one will only succeed in deceiving with"
# ------ temperature: 0.2
# ducation and culture
# one will only succeed in deceiving with the strength of the problem has a states of the same the sense of the same the commanders of the same the great sufficiently and superstition of the sense of the same the world as the same artists the same the strong the same the great problem and souls, and in the same the soul of the same the higher and proved the same condition of the sense of the subject of the most desire of the senses the w
# ------ temperature: 0.5
#  sense of the subject of the most desire of the senses the world, and say in perhaps they make the
# lower
# and
# sufficient in the best the fear--the best decisable in its own slaves and far the soul.
#
# 22
#
# =whoe the same motives all
# the experience, has so that their will" of himself and in such as in the former and that the races of the intellich the former leading and deepernation in the same time become the world and the strength to many as an indiance his s
# ------ temperature: 1.0
# come the world and the strength to many as an indiance his subject for -since of formor the case
# himself plack formed, wifhing enchantments, are or is history self-dreve,ing,
# and inasminith the great philolor of excessed could gaen from the contemporary philosophers, spiritually case of spirits, whereas oneal whose little petsing in gign string suffic---namely modern imprise--as into amould philosopher: they always and moreoof is our sahy, seemint. the dif
# ------ temperature: 1.2
# opher: they always and moreoof is our sahy, seemint. the differingers- self-frangs upinagness, deceive become, himself--mow.
#
#
# 10
#
# =not, his enterience of itild are retircents that."
#
#
# muhes, sarrin, of
# sortorious, of the great sutnest pausy of all thesse nehuns "deep soold, there shall always necoinbed from they
# emanciative, always finawant for
# one means picumely
# further all, he would be point
# in
# the genuiness degree carometic self
# =of anxiquate suir, an
# epoch 58
# Epoch 1/1
# 200278/200278 [==============================] - 333s 2ms/step - loss: 1.2405
# --- Generating with seed: "impulses of his nature
# stand to each other.
#
# 7. how maliciou"
# ------ temperature: 0.2
# impulses of his nature
# stand to each other.
#
# 7. how malicious the world is the world and suffering the same to the same time the strength of the same time the same things and suffering to the former and stronger the moral the strength of the sense of the sense of the sense of the strength of the same to the sense of the same to the strength of the same time the suffering the spirit of the same time the sense of the sense of the same time and soul of the sa
# ------ temperature: 0.5
# e the sense of the sense of the same time and soul of the same man
# and persons, and in the senses in the desist and more interest of his stopen spirit and the best of a desires of the spirit of the philosophers, and self state of every very being and forms of things as the same time a being is a manifests and decise of the extravious pleasure and the warticism who has the world of the external self as a constraint as the mothers of the bedne find a philoso
# ------ temperature: 1.0
# f as a constraint as the mothers of the bedne find a philosophers.
#
# 1111elely flority, and also a strong the worldly, prude and its relie toot-saniount.
#
# 8
# =wounds, and or one's bepthations, and and the devisen,
# that which is galvelfly it is him, will standing that "unsouls--or to each grateful good. the doubile--the
# beautiful ood.
#
#
# 12
#
# =not even of desens ill good pet of sort are defem-light" has deed not "truth of the rearing," and also the orha yet int
# ------ temperature: 1.2
# s deed not "truth of the rearing," and also the orha yet intaliteonal of his cleveluin starspler, are let
# dand, there, in it is to be
# conssching the
# himself of enemocks,sheted. to make them,
# almost anxiet
# for ditay worth muta, friends.
#
# ines of ever other condeatted unequalityceful, state and asteckly looks. even the virtue,
# which is from
# the later, in all a rorous, and child he wise ley of morality. among-human must
# hangefully ourselves.
#
# 178. doctises of
# epoch 59
# Epoch 1/1
# 200278/200278 [==============================] - 330s 2ms/step - loss: 1.2417
# --- Generating with seed: "some, steady process of science (which now for the
# first tim"
# ------ temperature: 0.2
# some, steady process of science (which now for the
# first time and there is the instinct of the more interpretation of the father and there are states and in the fact that it is a subjection of the states in the present and the present to the consideration of the same things in the sensations and such a superiority of the more sensations and subject that the same to the more delicate and the proper to the same to the more as a consideration of the same to t
# ------ temperature: 0.5
#  to the same to the more as a consideration of the same to the world in the present and deared from that he is certain interrorable in their sensations of evil and conceals which many a religious has view of the other and these hardness at the father and far too litative life in its long to european flower than woman which no well of the standard in the thing to best, as he sees to have to do
# the entire to philosophers--which at the posint that which there
# ------ temperature: 1.0
# entire to philosophers--which at the posint that which there are right "things, in them for life and characteristic is apprature and reness hin taste.
#
#
# 12
#
# =i re anxietie father as inaccessities. i instant comparation, in morality in unhigh manner deep conssquence that stame a religious
# of his and blanings"
# even to failure with this elevation.=--just very manifessings to pure not something in the fathed.
#
#
# 18
#
# =etern himself of more belong ao freedom that
# ------ temperature: 1.2
#  fathed.
#
#
# 18
#
# =etern himself of more belong ao freedom that the wild proquet of revoality sole-too--or tendency art, wsenfoldena of them: blablismocies
# and symptoms, but. thy great grown to them midday-must, a "dossans: you of
# a metaphysic
# cased in every greatest than a capabilen
# many way balus creating, is laws, from with the
# questions
# state of maned new man stry, much "one withse
# day
# on hoursic manifest, with nomicated be; -or of
# suddenly circumstances:

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.

# %% [markdown]
# ## **Saving model**

# %%
model.save('/content/drive/My Drive/test.hdf5')

# %% [markdown]
# ## **Loading model**

# %%
keras.models.load_model('/content/drive/My Drive/test.hdf5')

# %% [markdown]
# # **Testing**

# %%
import random
import sys

# Select a text seed at random
start_index = random.randint(0, len(text) - maxlen - 1)
generated_text = text[start_index: start_index + maxlen]
print('--- Generating with seed: "' + generated_text + '"')

for temperature in [0.2, 0.5, 1.0, 1.2]:
    print('------ temperature:', temperature)
    sys.stdout.write(generated_text)

    # We generate 400 characters
    for i in range(400):
        sampled = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(generated_text):
            sampled[0, t, char_indices[char]] = 1.

        preds = model.predict(sampled, verbose=0)[0]
        next_index = sample(preds, temperature)
        next_char = chars[next_index]

        generated_text += next_char
        generated_text = generated_text[1:]

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print()
# Out:
# --- Generating with seed: "-and should--appear as follies, and under
# certain circumstan"
# ------ temperature: 0.2
# -and should--appear as follies, and under
# certain circumstances, and there is the world of th
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# e consequently a subjection of the states and something in their sensations of the conscience of the same to the world of the same to the same things with the sense of the states of the same to the same to the present such a delicate and the experience of the same and the world of the same to the father and in the same to the more than the consequently and the cons
# ------ temperature: 0.5
# d in the same to the more than the consequently and the consideration of the instinct and and than his same that for the reductions of the whole of the same than things have a pasts and and something which the
# popularity and manifests a pain and distinguished by the pritation of the same and consideration, the german saints of the best about any one in its owing to the consciences, and that the
# present and more condition of a thing to the did not as sensat
# ------ temperature: 1.0
# esent and more condition of a thing to the did not as sensation
# of his passions of more himself, to
# his one man is everything--thinkings. they wronger that refulties and any betormation has
# to the count long-grain and radicy to best the greatest than has free bies dreams formulo of
# its great what instinctism in wild a consideration of welling dispresirit of many how the
# identmness, has to trangeted
# ifure
# ignated
# enpurer as a sunsels one formst" in it, "eve
# ------ temperature: 1.2
# d
# ifure
# ignated
# enpurer as a sunsels one formst" in it, "every cannot
# supies with thinkering-doubt they reight--guilt revertils, in the art of feprases to purited
# one on the semitical nature
# last the slave" come
# satisfaction to appreciative namely
# east one hartyses works me. wild thy more experience and
# enchan isy. slale and ley. here,
# this seful
# honoure upsoem dinition of ane"; inkjoyund--nothing and eachens would to that effects. deapily of the veighlese
